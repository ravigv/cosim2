# %%
# %%time

import os
import re
import string
import pprint

import pandas as pd
import numpy as np

import gensim
# Out:
# Wall time: 0 ns

# %%
# %%time

# change working directory

print('Before chdir:', os.getcwd())

os.chdir('F:\\CG\\w2vCustom') 
         
print('After chdir:', os.getcwd())
# Out:
# Before chdir: C:\Users\Ravi
# After chdir: F:\CG\w2vCustom
# Wall time: 1 ms

# %%
# %%time

df=pd.read_excel("wb_causecode_asgrp.xlsx");

df.head()
# Out:
# Wall time: 23.5 s
#   account                          app_name                    assigned_group  \
# 0      wb                               NaN                   WBEI.Sharepoint
# 1      wb     SAP Accounts Payable/Workflow  WBEI.MKTMGT.Siebel North America
# 2      wb                               NaN                   WBEI.MIS.Alfred
# 3      wb  SAP Netweaver Business Warehouse          WBEI.BW - Data Warehouse
# 4      wb                            System        WBEI.WBCAS Adobe LiveCycle
#
#   causecode_lv1  causecode_lv2                                  causecode_lv3  \
# 0        Access          Issue                   Unable to access application
# 1        Delete  Data Deletion                        As per user requirement
# 2        Access      Approval   Access/SAP Issue/Unable to access environment
# 3        Access      Approval   Access/SAP Issue/Unable to access environment
# 4        Access      Approval   Access/SAP Issue/Unable to access environment
#
#     incident_id                                            summary
# 0  RTASK0033182                User cannot access Time-Off Tracker
# 1  RTASK0086491  Promo1169410 ACB#236740 Deal Status "Payment i...
# 2  RTASK0106734  Error messge stating that the Alternate Payee ...
# 3  RTASK0246906  FRB Reconciliation need to be perform on 06/04...
# 4  RTASK0286950  !! URGENT-- Forward eform 11828 to another app...

# %%
# %%time

# Check missing values in a dataframe
# df.isnull().values.any()
# Out:
# Wall time: 0 ns

# %%
# %%time

# Function to keep required columns in a dataframe

def keepcols(df, cols):
    '''
    df = dataframe
    cols = list of columns to keep in df 
    '''
    
    cols_keep = [cols[0], cols[1], cols[2], cols[3]]
    return df[cols_keep]
# Out:
# Wall time: 0 ns

# %%
# %%time

# Subset required columns
df1 = keepcols(df, ['causecode_lv1', 'causecode_lv2', 'causecode_lv3', 'summary'])

df1.head()
# Out:
# Wall time: 16 ms
#   causecode_lv1  causecode_lv2                                  causecode_lv3  \
# 0        Access          Issue                   Unable to access application
# 1        Delete  Data Deletion                        As per user requirement
# 2        Access      Approval   Access/SAP Issue/Unable to access environment
# 3        Access      Approval   Access/SAP Issue/Unable to access environment
# 4        Access      Approval   Access/SAP Issue/Unable to access environment
#
#                                              summary
# 0                User cannot access Time-Off Tracker
# 1  Promo1169410 ACB#236740 Deal Status "Payment i...
# 2  Error messge stating that the Alternate Payee ...
# 3  FRB Reconciliation need to be perform on 06/04...
# 4  !! URGENT-- Forward eform 11828 to another app...

# %%
# %%time

# Check for missing vlaues after iputation in a dataframe

print("Before", df1.isnull().values.any())


# check and impute missing values in a dataframe


df1 = df1.fillna('')
df2 = df1.head(5000)

print("After", df1.isnull().values.any())
# Out:
# Before True
# After False
# Wall time: 55 ms

# %%
# %%time

def combined_features(df):
    combi_feats = []
    for i in range(0, df.shape[0]):
        combi_feat = df['causecode_lv1'][i]+' '+df['causecode_lv2'][i]+' '+df['causecode_lv3'][i]+' '+df['summary'][i]
        combi_feats.append(combi_feat)
    
    return combi_feats




#          combi_feat = df['causecode_lv1'][i]+' '+df['causecode_lv2'][i]+' '+df['causecode_lv3'][i]+' '+df['summary'][i]  
#         combi_feat = df[lstcols[0]][i]+' '+df[lstcols[1]][i]+' '+df[lstcols[2]][i]+' '+df[lstcols[3]][i]
#         combi_feat = df.loc[i,lstcols[0]]+' '+df[i, lstcols[1]]+' '+df[lstcols[2]]+' '+df[i, lstcols[3]]
# Out:
# Wall time: 0 ns

# %%
# %%time

df2['combined_feats'] = combined_features(df2)
df2
# Out:
# Wall time: 169 ms
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      causecode_lv1  causecode_lv2  \
# 0           Access          Issue
# 1           Delete  Data Deletion
# 2           Access      Approval
# 3           Access      Approval
# 4           Access      Approval
# ...            ...            ...
# 4995        Access          Issue
# 4996        Access        Request
# 4997        Access        Request
# 4998        Access          Issue
# 4999       Request        Enquiry
#
#                                       causecode_lv3  \
# 0                      Unable to access application
# 1                           As per user requirement
# 2     Access/SAP Issue/Unable to access environment
# 3     Access/SAP Issue/Unable to access environment
# 4     Access/SAP Issue/Unable to access environment
# ...                                             ...
# 4995                   Unable to access application
# 4996                                  Remove Access
# 4997                                     New Access
# 4998                  Unable to access environment
# 4999                                    Information
#
#                                                 summary  \
# 0                   User cannot access Time-Off Tracker
# 1     Promo1169410 ACB#236740 Deal Status "Payment i...
# 2     Error messge stating that the Alternate Payee ...
# 3     FRB Reconciliation need to be perform on 06/04...
# 4     !! URGENT-- Forward eform 11828 to another app...
# ...                                                 ...
# 4995  TOBI_Request for BO user account creation- XKB...
# 4996               Leavesden Leavers - 9/29 & 10/1/2017
# 4997  update XSBOMMAR in WPP to assign WZ:605 and re...
# 4998                     [URGENT] Office 2016 migration
# 4999  Business is looking for steps and SAP screen s...
#
#                                          combined_feats
# 0     Access Issue Unable to access application User...
# 1     Delete Data Deletion As per user requirement P...
# 2     Access Approval  Access/SAP Issue/Unable to ac...
# 3     Access Approval  Access/SAP Issue/Unable to ac...
# 4     Access Approval  Access/SAP Issue/Unable to ac...
# ...                                                 ...
# 4995  Access Issue Unable to access application TOBI...
# 4996  Access Request Remove Access Leavesden Leavers...
# 4997  Access Request New Access update XSBOMMAR in W...
# 4998  Access Issue Unable to access environment  [UR...
# 4999  Request Enquiry Information Business is lookin...
#
# [5000 rows x 5 columns]

# %%
# %%time

import re
from gensim.parsing.preprocessing import remove_stopwords

# Preprocess text for summary
def clean_sentence(sentence, stopwords=False):
    
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    #lower case 
    sentence = sentence.lower()
    # square brackets
    sentence = re.sub('\[.*?\]', '', sentence)  
    # hyperlinks
    sentence = re.sub('https?://\S+|www\.\S+', '', sentence)
    sentence = re.sub('<.*?>+', '', sentence)
    # remove punctuation
    sentence = re.sub('[%s]' % re.escape(string.punctuation), '', sentence)
    sentence = re.sub('\n', '', sentence)
    # remove year
    sentence = re.sub(r"\b(19[40][0-9]|20[0-1][0-9]|2020)\b",'',sentence)
    # remove month names
    mp = r"(\b\d{1,2}\D{0,3})?\b(?:Jan|jan(?:uary)?|Feb|feb(?:ruary)?|Mar|mar(?:ch)?|Apr|mar(?:il)?|May|may|Jun|jun(?:e)?|Jul|jul(?:y)?|Aug|aug(?:ust)?|Sep|sep(?:tember)?|Oct|oct(?:ober)?|(Nov|nov|Dec|dec)(?:ember)?)\D?(\d{1,2}(st|nd|rd|th)?)?(([,.\-\/])\D?)?((19[7-9]\d|20\d{2})|\d{2})*"
    sentence = re.sub(mp, '', sentence)
     
    # remove words containing numbers
    sentence = re.sub('\w*\d\w*', '', sentence)
    # remove numbers 
    sentence = re.sub(r'[0-9]+','',sentence)
    
    if stopwords:
        sentence = remove_stopwords(sentence)
    
    return sentence
# Out:
# Wall time: 0 ns

# %%
# %%time

def get_cleaned_sentences(df, col, stopwords=True):
    cleaned_sents = []
    
    for index, row in df.iterrows():
        cleaned = clean_sentence(row[col])
        cleaned_sents.append(cleaned)
    return cleaned_sents


# Calling the function get_cleaned_text

cleaned_sentences = get_cleaned_sentences(df2, 'combined_feats')
cleaned_sentences
# Out:
# Wall time: 835 ms
# ['access issue unable to access application user cannot access timeoff tracker',
#  'delete data deletion as per user requirement   deal status payment in progress with no payment',
#  'access approval  accesssap issueunable to access environment error messge stating that the alternate payee group does not exist',
#  'access approval  accesssap issueunable to access environment frb reconciliation need to be perform on  ',
#  'access approval  accesssap issueunable to access environment  urgent forward eform  to another approver',
#  'request enquiry information report migration from dev to qa',
#  'access request unlock disable ei batch jobs',
#  'access request unlock complete request  general service request',
#  'access request remove access hpqc access to project workday domain mis  id xvdhake',
#  'access issue unable to access environment  help withsetting up cbs profile in wbconnect',
#  'access request unlock route ticket to new approver',
#  'access request unlock proactive breakfix  incident ticket for  monthly release into production',
#  'access issue unable to access environment  add an approver to hierarchy',
#  'data request quantity change change order in cbs',
#  'access issue unable to access environment  substitute approver',
#  'access request unlock need  to configure drivers in order to refresh lumira on bi launchpad ',
#  'access request unlock  assistance with filling out ',
#  'access request unlock proactive emergency breakfix  incident ticket for   monthly release into production',
#  'access request add email id eform ',
#  'application batch job failure list of people who have role for company code ',
#  'access approval  accesssap issueunable to access environment complete request  general service request',
#  'access approval  accesssap issueunable to access environment please migrate the bo objects from  to ',
#  'data shopping cart shopping cart error master ticket for srm change order issues',
#  'data request data update request modify riverbed settings to support teradata data migration per bobby paik',
#  'access request unlock urgent  complete request  general service request',
#  'access approval  accesssap issueunable to access environment error when trying to log in to ',
#  'access approval  accesssap issueunable to access environment request for new sharepoint path',
#  'access approval  accesssap issueunable to access environment adobe eforms  attention required  eform  request form for applicant matthew leos',
#  'invalid request error found big  sap edit error  needs assistance on how to clear these labor errors',
#  'data data flow data flow failure tpx gen  transmissions',
#  'general request general service request remediation items for treasury hedging database',
#  'access approval  accesssap issueunable to access environment to get operative one configuration informations',
#  'access approval  accesssap issueunable to access environment clscritical transmission ',
#  'request enquiry information update to wb property department website front page',
#  'application upgrade new version maccs germany  i cannot save the  vat report in pdf',
#  'request enquiry information  lift the validation for gl accounts',
#  'request enquiry information master ticket for buffer table related issues',
#  'application issue billing issue inymbus issue  cases on deniedwb status that need to be resubmitted to wm portal',
#  'request enquiry analysis  bachelor  exceptions   and  ',
#  'access request account creation jobs failed in cmp ',
#  'serverservicewebsite connection issue services are down please maintain relationship for business partner  hiroki tanzawa',
#  'access issue unable to access application please help resolve psl exception report for ellen  series',
#  'access issue unable to access environment  process the deal  from ps to  ',
#  'access issue unable to access environment  process cosmos deal bp master and bp relations for deal line ',
#  'access request access modification sap crm adobe eforms  attention required  eform  request form for applicant leo mylonadis',
#  'request enquiry information extend mpm s  and  to intl tv cosmos sales orgs',
#  'request enquiry information report scheduling to sharepoint',
#  'general request general service request manual run for blindspot   cast payment',
#  'data transaction issue transaction not posted in destination system vendor showing as open is ed for deletion',
#  'access request account creation please help resolve psl exception report for ellen ',
#  'access issue unable to access application wbei outage initial notice',
#  'access request unlock please change pw for tmsadm in  sapcpic in   and sap in ',
#  'data transmission issue trasmission not appearing in target system please investigate exceptions on project mix psl exception report ',
#  'request enquiry information data recon tool issues for blindspot  series',
#  'request enquiry information data recon tool issues for horizon alternative ',
#  'request enquiry information data recon tool issues for snu project',
#  'access sap issue unable to access environment  requirement for sox audit',
#  'access issue unable to access environment  adobe eforms  attention required  eform  request form for applicant man chan',
#  'data transmission issue trasmission not appearing in target system tmz   new exception report',
#  'request enquiry information clscritical revaluation posted in co code  for transaction currency eur isnt correctly calculated',
#  'access request access modification create the deal  idoc into ',
#  'request enquiry information invoice issue  wrong vat number',
#  'general request general service request newly included languages not flown to nts and titles not flowing down to nts ',
#  'request enquiry information flash  issue with ultimates submissionretraction',
#  'request enquiry information flash  incorrect data in dubbing for  ts rfcst for mpm ',
#  'request enquiry information please run a vendor spend report for all software vendors pononpo to include tax code and tax amount from  present ',
#  'data mismatch records missing in table the following episodes of famous in love is not flowing to nts episode id     ',
#  'data mismatch duplicate entry doubling in     hierarchy for ',
#  'access issue unable to access environment  rename the current sylvester tab in bw portal to participations allocation',
#  'data request data update request complete estimate ',
#  'application batch job failure dvm analysis for technical tables in all systems',
#  'access issue unable to access environment  add zsox to auditor role in all sox systems ',
#  'access issue unable to access application can you please process the following deal updoctest to  please let me know if you need further details',
#  'general request general service request studionet possible smb bruteforce activity against studionet system',
#  'application batch job monitoring   utility program crmdcustomeri sync issue monitoring',
#  'data request test data helped hasit on testing part of incident  ',
#  'data validation validation failed plant grid validation',
#  'application code bug fix   close  sap  incorrect values',
#  'access request unlock complete request  general service request',
#  'access approval  accesssap issueunable to access environment complete request  general service request',
#  'data request test data test scenarios has been performed and helped hasit regarding ',
#  'request estimate enhancement complete estimate ',
#  'application code bug fix send only the exclusive territory holdbacks to cosmos',
#  'application code bug fix remove avod svod and linear holdbacks and stage only the est and tvod',
#  'application code bug fix one time conversion to restage the deals to sync holdbacks with cosmos',
#  'configuration mapping error error found psl to sap transfer issue snu project',
#  'service request service requests  batch job requested urgent consignment difference report zmmcondiff  set up scheduled job ',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant syawariya tapesh',
#  'application batch job monitoring cosmos batch job lists',
#  'application issue ui refresh issue adding movie run',
#  'access request unlock complete request  general service request',
#  'access issue unable to access application tdm production cost details report issue',
#  'access issue unable to access application please fix pds rsparam config per attached ',
#  'access issue unable to access application create web services in bds for sl hub alert configuration',
#  'access issue unable to access transaction cosmos network sales rtpm',
#  'general request general service request clearpass servers  configure systems to log centrally to  ',
#  'data request data update request complete request  general service request',
#  'data mismatch records missing in table ticket for the team',
#  'request enquiry information complete estimate ',
#  'access sap issue unable to access environment  complete request  sap system open access process',
#  'access request password reset monitoring services  great plains ar',
#  'access request password reset request tabl auth for sctsadmi object be removed from all roles except basis charm and  be added to develop team role across all systems ',
#  'request enquiry information zp doctypes not being cleared properly ',
#  'request estimate enhancement  estimate two issues with vendor updates in psl',
#  'data missing field missing in documents crm estimate effort to turn rim off for carrefour france',
#  'request enquiry information  clear code sap',
#  'application code bug fix unable to reject the item',
#  'request enquiry information  reopen profit center',
#  'application bdoc monitoring bdoc monitoring   ',
#  'application reporting for week reporting for the week    ',
#  'application reporting for week fa reporting for the week   ',
#  'request enquiry information  change approver for mdh',
#  'data request data update request exclude prs from vanmodautopocreate job',
#  'access request account creation unlock printer achk in ',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant zalesinski radoslaw',
#  'request enquiry information stars new season calendars for ',
#  'access issue unable to access environment  iwbepsp access to basis admin role',
#  'application monitoring healthcheck slhub  workday timer performance issue',
#  'archival request backuprestore stars archival  season',
#  'request enquiry information stars archival  season',
#  'data data load issue data load failed brazil missing bookings for ',
#  'data data load issue data load failed brazil missing bookings lego batmankong skull island  king arthur the legend of the sword',
#  'data data load issue data load failed stars bo load dayparts ',
#  'archival request backuprestore archive  stars database',
#  'data request data update request urgent  complete request  general service request',
#  'access issue unable to access application sap  access request',
#  'data data load issue data load failed brazil missing bookings for ',
#  'request enquiry information urgent  complete request  change or configure an application',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant alam md shahbaz',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant asif shaik',
#  'application code bug fix stars license fee change email notification list',
#  'general request general service request please confirm the job list from your team to test them on pds server',
#  'request estimate testing stars dev vip',
#  'request enquiry information master data hub approver change',
#  'data mismatch records missing in table data flow issue from sap to ',
#  'data request data update request issue downloading cosmos file report to be converted to excel ',
#  'access request password reset estimate  web service call zmcreatedigitalmaterial',
#  'application configure request change or edit the application biannual audit clean upplease update the following request types in the mdh that have been identified now as ',
#  'report request report run query the mdh database to inlcude the all fields listed in the request types screen see screen shot attached',
#  'request enquiry information sap finance team ticket ',
#  'access issue unable to access application cms theater details from maccs to tobi',
#  'access request unlock complete estimate ',
#  'general request general service request  sapgui install request',
#  'access request unlock complete estimate ',
#  'request enquiry information  how to research the franchise',
#  'data mismatch incorrect data found amazon de    de  amazon eu sarl  sap   aic audit',
#  'data mismatch incorrect data found asda uk      sap   aic audit',
#  'report request report run master data hub  new tax code ',
#  'report request report run brazil missing bookings for ',
#  'report request report run grant read only access to navision corporate  archive  leavesden also install the app on her laptop',
#  'application configure request change or edit the application mdh hub home page scrolling message update needed with upcoming freeze dates',
#  'application configure request change or edit the application mdh improvement request as created by andrew b prior to his departureplease review and provide a status update by ',
#  'request enquiry information mdh new user welcome email and communication including revised user intake requirements please see email attachment and instructions provided earlier this week',
#  'access request unlock owning company code repost  manual activity for  and  scenario',
#  'request enquiry information access to master data hub',
#  'data data flow data flow failure customer status in sap',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant sternberg ashley',
#  'access issue unable to access application urgent  complete request  general service request',
#  'application code bug fix amazon schedule line item issue breakfix',
#  'application ip data data cleansing changes for the list of    ips for updating the itdi release windows and wbheg profile',
#  'access issue unable to access environment  complete request  general service request',
#  'application  testing dtd invoice printing fat in ',
#  'access issue unable to access application cmsbrazil missing bookings for the titles',
#  'request enquiry information us theatrical release date for  titles not being interfaced to ipm',
#  'request enquiry information edi invoices question re carrefour spain',
#  'request estimate enhancement single sign on for stars',
#  'data transmission issue trasmission not appearing in target system rtprosluk prd transmissions pdfs not found after ',
#  'access request access modification sap access request form – attention required – request form for applicant thimmaiah shilpa',
#  'access request access modification sap access request form – attention required – request form for applicant leu michelle',
#  'access issue unable to access application plm  determine location of component type to gl account mapping for plan vs actuals reports',
#  'data mismatch incorrect data found sap  positive pay file not valid',
#  'access sap issue unable to access environment  complete request  general service request',
#  'application deal inclusion list qa approval  ',
#  'data transaction issue transaction not posted in destination system check the configuration in sap for the newly created tv production comp codes',
#  'request enquiry information complete request  general service request',
#  'access request new access    request for reverse gr of po ',
#  'application deal cancellation issue request you to cancel the below listed scope in  system',
#  'data transaction issue transaction not posted in destination system checks are failing to post in sap from lob systems',
#  'request enquiry information difference in records',
#  'access issue unable to access application complete estimate ',
#  'request enquiry information urgent  complete estimate',
#  'general request general service request can you please check and let us know the below listed ar account status in gp',
#  'report request report run  estimate request for ers  change to  limit threshold of electronic invoices',
#  'request enquiry analysis  reload actual excluding year  in ',
#  'access request new access  sap access request form – attention required – request form for applicant housley torree',
#  'data transmission issue trasmission not appearing in target system rimca  on hands in rim are not being adjusted for bby ca',
#  'access issue unable to access environment  provide access to schema wbdsupply in bhd for user xgpurams',
#  'access request unlock sap',
#  'request enquiry information  status but should not be',
#  'access request access modification authorization issue while activating the service in bds system',
#  'application issue not accessable users not able to work on  and emails not received',
#  'access request access modification   sap access request form – attention required – request form for applicant eshima natsuko',
#  'sap dumps issue runtime error dumps urgent  complete request  general service request',
#  'data data load issue data load failed batch balancing issue',
#  'access request account creation   sap access request form – attention required – request form for applicant mustafa shadab',
#  'access request new access sap access request form – attention required – request form for applicant mustafa shadab',
#  'access request access modification sap access request form – attention required – request form for applicant kumar periwal anuj',
#  'request enquiry information  request to update bank details',
#  'request estimate enhancement complete estimate ',
#  'access request new access sap access request form – attention required – request form for applicant chu alvin',
#  'request estimate testing testing effort for window  upgrade',
#  'general request general service request please investigate these stuck transmissions and help us to understand reason for failure',
#  'data transmission issue idoc failure   outbound  idocs  status  debmas ',
#  'data issue incorrect data in backend sap security please provide role for zmpmmaint',
#  'request enquiry information  access on sap',
#  'application deal inclusion list qa approval  ',
#  'general request general service request provide lob details for transmission',
#  'access issue unable to access application  trace giving dump',
#  'data validation validation failed rim  pack product discrepancy',
#  'request enquiry information   sap  bank number field is longer than  characters',
#  'data mismatch records missing in table  there is some data flow issue from sap to  for the following titles',
#  'access request access modification  sap access issue',
#  'report request report run rim team to run a walmart oh report for   going in style dvd include total mins',
#  'data mismatch duplicate entry master data team to update the cons unit  in     doubled up',
#  'access request unlock complete request  general service request',
#  'serverservicewebsite connection issue services are down sps commerce edi  system maintenance   cst',
#  'data data load issue data load failed  tx shuttle script to reject po line items is not working',
#  'request enquiry information modify balance in group mpm',
#  'authorization issue user understanding issue  purchase order ',
#  'access request remove access  starters leavers ',
#  'access issue unable to access environment  remove profit center and company code combination check in  and ',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant mehrzai faisal',
#  'access request access modification sap access request form – attention required – request form for applicant canasi brittany',
#  'request estimate testing testing production accouting interfaces following security upgrade',
#  'access approval  accesssap issueunable to access environment plm process chain monitoring for week  to ',
#  'access approval  accesssap issueunable to access environment plm portal health check for week  to ',
#  'data mismatch data reconciliation daily idocs reconciliation carried out on   ',
#  'access request access modification error in sap access form',
#  'access approval  accesssap issueunable to access environment cosmos itd and dtd bwp monitoring for the week starting from  to ',
#  'access request provide access add user urgent  complete request  general service request',
#  'report request report run move the submissions to shooting stars office',
#  'request enquiry information  issue with sap ',
#  'request enquiry information urgent  complete request  general service request',
#  'serverservicewebsite connection issue services are down  bw load status needed',
#  'request enquiry information mdh ',
#  'request enquiry information mdh ',
#  'access issue unable to access application admnessbase monitoring weekly backup plmand optimization ',
#  'jobprocess schedule  run jobs  backups admn  incident report extraction',
#  'request estimate enhancement slhub dependency removal',
#  'application monitoring healthcheck cosmos fccdtd jobs monitoring',
#  'request enquiry information complete request  general service request',
#  'access issue unable to access environment  inquiry about roles',
#  'access request access modification   sap access request form – attention required – request form for applicant haque shafia',
#  'data mismatch incorrect data found technicolor north america   sla breach  ',
#  'request enquiry information cadency balance issue reocurring ',
#  'access request new access sap access request form – attention required – request form for applicant cho johnna',
#  'access request new access sap access request form – attention required – request form for applicant eckerle glenn',
#  'access request new access sap access request form – attention required – request form for applicant reyter elena',
#  'access request new access sap access request form – attention required – request form for applicant rodriguez natalie',
#  'access request access modification request for cbs application portal role details to access documents from wb portal',
#  'access request access modification sap access request form – attention required – request form for applicant huynh david',
#  'access request new access sap access request form – attention required – request form for applicant darden briar',
#  'data request data update request create  new sap zvvr sub brand',
#  'access request new access sap access request form – attention required – request form for applicant rideout joi',
#  'access request access modification sap access request form – attention required – request form for applicant riley christopher',
#  'access request access modification sap access request form – attention required – request form for applicant rey richard',
#  'access request access modification sap access request form – attention required – request form for applicant dalglish charles',
#  'request estimate enhancement bwupdate email config to point cycle for bcs  ',
#  'application monitoring healthcheck event builder map upload',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant brown krystle',
#  'access issue unable to access application create hana studio users in hana db soq and sod',
#  'data data flow data flow failure pslsap issues  constantine  pilot',
#  'data data flow data flow failure recon tool issue  shameless  series',
#  'request enquiry information sap production cost data missing from  interface',
#  'order po issue po not generated correctly    failure',
#  'data data flow data flow failure pslsap issue  mom  series',
#  'data data flow data flow failure pslsap issue  shameless  series',
#  'data data flow data flow failure pslsap issue  gilmore girls  series',
#  'access request account creation provide access for sap solution manager',
#  'access request unlock complete request  general service request',
#  'data mismatch records missing in table push the idocs for under suspicion with mpm  ',
#  'access request password reset statement report    gp',
#  'request enquiry information create a test id ',
#  'access issue unable to access application we are getting time out error in bo for large selections in production can you please send the output file and no of records for below selections we do not ha',
#  'authorization issue maintain table entry add the user in the distribution list',
#  'data data load issue missing flash afc   not assigned amount',
#  'access request account creation complete request  general service request',
#  'access request new access sap access request form – attention required – request form for applicant jedamzik nicolai',
#  'access request access modification sap access request form – attention required – request form for applicant jedamzik nicolai',
#  'access request access modification urgent  complete request  change or configure an application',
#  'access approval  accesssap issueunable to access environment could you please check below ewa report and fix the issue in scp',
#  'access request account creation data in the report for the source ',
#  'data mismatch records missing in table push the materials sap to siebel',
#  'data mismatch incorrect data found maccs booking admission numbers change',
#  'access request access modification sap access request form – attention required – request form for applicant scott briony',
#  'access request access modification   sap access request form – attention required – request form for applicant heron scott',
#  'access request new access sap access request form – attention required – request form for applicant nichol chelsea',
#  'access issue unable to access environment  dezactivation sap',
#  'request estimate enhancement estimate el corte ingles slsrpt rff segment and ve qty change',
#  'request enquiry information  match and clear  issue',
#  'access issue unable to access application please investigate why qar based bpp errors are being generated',
#  'data request data update request complete estimate ',
#  'access request access modification sap access request form – attention required – request form for applicant speckman deborah',
#  'request enquiry information  vendor changes on ',
#  'access request account creation complete request  general service request',
#  'data data flow data flow failure pslsap issue  gilmore girls  series  ',
#  'data data flow data flow failure pslsap issue  gilmore girls  series  ',
#  'request enquiry information man of steel request ',
#  'access request access modification sap access request form – attention required – request form for applicant dl prakruthi',
#  'access request new access   sap access request form – attention required – request form for applicant inukai charissa',
#  'access request new access sap access request form – attention required – request form for applicant inukai charissa',
#  'access request access modification   sap access request form – attention required – request form for applicant cooper elana',
#  'access request new access mdh new user to the mdh hub please create a profile and gather all necessary requirements to complete the user profile ',
#  'request enquiry information complete request  general service request',
#  'data data flow data flow failure pslsap issue  gilmore girls  series   thru ',
#  'access request new access mdh hub new user request please set up a profile for eric wilker please see attached email for additional areas in which he will approve',
#  'application configure request unable to approve mdh approver updates as lee fraiser has moved to a new department please gather all necessary updates to update his mdh profile and list of sap md request type',
#  'access request new access mdh requester profile update please see attached and contact user for all mdh profile information required',
#  'general request estimate complete estimate ',
#  'application deal deal header error clscritical deal  scopes    error rights dim values of rd and rfd do not match',
#  'configuration request feed fiji dollars in sap',
#  'upload failure bad file bank accounts not interfacing properly with gl accounts',
#  'request enquiry information  equity reconciliations issue sap',
#  'service request service requestanalysis we have an issue with the cosmos payment register report where the invoice document is having incorrect amount in column total invoice amount tc',
#  'authorization request user request to grant access   urgent  complete request  general service request',
#  'data request data report please generate a vm report',
#  'access request unlock please set up popup message system is currently being used for fiscal year change testing so please log off if any issue is there in    systems',
#  'request enquiry information  account cash ',
#  'general request general service request role change for sap id smsop in xrp',
#  'access request access modification   urgent  sap access request form – attention required – request form for applicant r natraj',
#  'access request password reset add a new vendor in sap',
#  'request enquiry information complete request  general service request',
#  'request enquiry information emea inter company issue track ',
#  'access request account creation  lost sap access  wbconnect password reset and lost',
#  'access issue unable to access application user roles wrongly removed due to  days inactive program error for user type ebponly in wpp and all child systems except',
#  'request enquiry information  difference between sub ledger account and currency exchange account cc ',
#  'data mismatch records missing in table urgent data flow issue from sap to ',
#  'access request new access program zfrrevenueadjustldauto cancellation of    documents are not generated',
#  'data validation validation failed rim  pack product discrepancy',
#  'access issue unable to access application please grant access to gator universe for attached user list',
#  'access request new access sap access request form – attention required – request form for applicant abrams stephanie',
#  'service request patch upgrade stars vulnerabilities',
#  'application dads data issue dealid and bpid not proceesed into dads from cosmos',
#  'data mismatch data reconciliation estimate best buy us   dummy sku fix on  idoc',
#  'access request access modification sap access request form – attention required – request form for applicant bhimani dipesh',
#  'report request report run material pricing grouprequired field',
#  'workflow issue table entry missing  sap main account configuration',
#  'application code bug fix complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant lobos hector',
#  'access request account creation complete request  general service request',
#  'access issue unable to access application wmdf  complete estimate',
#  'application code bug fix wmdf  fcst does not match flash',
#  'authorization request user request to grant access   complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant cross kimberly',
#  'access issue unable to access environment    complete request  general service request',
#  'data request data update request complete request  general service request',
#  'access request new access mdh new user request set up for steve elsa',
#  'access sap issue unable to access environment  sap access',
#  'general request general service request actor fees not calculating correctly',
#  'access issue unable to access application update mapping to llp detailed ultimates and ',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant ahn so yoon',
#  'data shopping cart shopping cart error  error in process',
#  'request enquiry information error after bu coder enhancement',
#  'data mismatch records missing in table we are facing the data flow issue  ratting from sap to    talent from val to ',
#  'access request password reset issue with access pages under citrix for capital budgeting system',
#  'access request new access sap access request form – attention required – request form for applicant glaser e',
#  'access request access modification sap access request form – attention required – request form for applicant glaser e',
#  'data mismatch records missing in table we are facing data flow issue from sap top  kindly find the attached the sap report for your reference',
#  'data mismatch records missing in table dataflow issue',
#  'data missing field missing in documents orders to techca failed at translation due to nonformatted text in  segment ',
#  'access issue unable to access environment   no credentials for wb connect',
#  'access request access modification sap access request form – attention required – request form for applicant mocko abbie',
#  'request enquiry information update the  close freeze dates in mdh calendar ',
#  'data request data update request dpm ca pos  consolidating gls ',
#  'access issue unable to access application bcs zotvarv period change for ',
#  'request enquiry information cadancy balance issue',
#  'access request account creation create exkviswar id in bwp',
#  'access request remove access distribution list memebership update update ',
#  'access request remove access amer ods  mdm load ',
#  'access request remove access gems ods  mdm  load ',
#  'access request access modification asia pacific ods for for jp failed due to invoice missing from maccs',
#  'request enquiry information mpm  reopening  scm is not able to reverse gr ',
#  'request enquiry information there is a difference between sub ledger and currency exchange account for cc ',
#  'access sap issue unable to access environment  please reactivate davids wb domain iddewing as he will need to access the mdh new sec policy indicates all mdh users must authenticate with a wb domain id',
#  'access request add mac address micros reset data ',
#  'access issue unable to access application   complete request  general service request',
#  'access request access modification bpc access request',
#  'access issue unable to access application sap access request form – attention required – request form for applicant shank shyla',
#  'application monitoring healthcheck slhub  salesforce page performance issue',
#  'access issue unable to access environment  sap access request form – attention required – request form for applicant chan jackie',
#  'access issue unable to access environment  please reset my sap bhd password',
#  'access request remove access sap access request form – attention required – request form for applicant church ',
#  'request enquiry information slhub access for salesforce support',
#  'access issue unable to access application   request for removing sap access',
#  'configuration request application complete request  general service request',
#  'access issue unable to access environment  complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant im jinny',
#  'authorization request user request to grant access complete request  general service request',
#  'access request new access plm  create new value consumer products for vendor field in trailer application',
#  'general request general service request   complete request  general service request',
#  'data transmission issue trasmission not appearing in target system complete request  general service request',
#  'access sap issue unable to access environment    need emergency access in bwp for exkviswar id',
#  'access request remove access amer ods  mdm load for ',
#  'access request remove access gems ods  mdm load for ',
#  'request enquiry information sap invoice',
#  'access request remove access wb account offboarding request sap',
#  'authorization request user request to grant access provide access for t code  in order to manually run funnelling job in dev system',
#  'access issue unable to access environment  the user requested that she needs access to bpc',
#  'application monitoring healthcheck   errors in scp clearing cif stuck queues  on ',
#  'request enquiry information clscritical group mpm splitter',
#  'application ip data data cleansing  error record',
#  'access request account creation complete request  reset sap support staff password',
#  'request enquiry information complete request  general service request',
#  'data mismatch data reconciliation daily idocs reconciliation carried out on   ',
#  'application monitoring healthcheck delete the slh logs from slhub dev qa  prd servers',
#  'application monitoring healthcheck daily monitoring file process and healthcheck for the  slhub application for week   ',
#  'application monitoring healthcheck daily monitoring file process and healthcheck for the  fringeengine application for week   ',
#  'application monitoring healthcheck gp file process and weekly filetwiddept process',
#  'request enquiry information complete request  general service request',
#  'access issue unable to access application extend sap account',
#  'access issue unable to access environment  sap business objects upgrade',
#  'request estimate enhancement complete estimate ',
#  'data issue latest data not available do the cost estimate for the materials in dev system',
#  'data data load issue data load failed target  technicolor   error  invalid purchase order number sent in the prf segment  ',
#  'request enquiry analysis  unable to access subtitle report',
#  'application monitoring healthcheck not able to log into master data hub access is already setup',
#  'access request account creation lost sap access ',
#  'application monitoring healthcheck rrts  health check and interface monitoring',
#  'application monitoring healthcheck ratings preprocessor  orsyp job monitoring',
#  'application code bug fix re batch job failur sf',
#  'request enquiry information manual interface from sap to cadency for ',
#  'application monitoring healthcheck plm health check and batch job monitoring for the  to ',
#  'general request general service request ppim qvc  ',
#  'request enquiry information otc qvc  kc   ',
#  'service request service requestanalysis zpccpuchorstd sap script  po box change analysis',
#  'application upgrade new version urgent import of the ebors not possible after germany maccs upgrade',
#  'general request general service request plm cutover testing activity',
#  'service request service requestanalysis change po job in prd updated the po but the job is showing the zcpr in error of ',
#  'request enquiry information nl transactions',
#  'configuration missing new transaction type invoice configuration changes',
#  'access issue unable to access environment  wb connect roles assignment request',
#  'access issue unable to access environment  sap user extension ',
#  'access request account creation sap user termination ',
#  'request enquiry information hi sap security team  we have b ids could you please match with one of my teamsap basis member id in bhp thanks rtask for the same  request you to give',
#  'data validation validation failed rim  pack product discrepancy',
#  'report weekly activity report creation splitter audit report for ',
#  'application monitoring healthcheck ldx server information',
#  'request enquiry information complete request  general service request',
#  'request enquiry information sweden just producesap interface errors as of ',
#  'access request access modification sap access request form – attention required – request form for applicant thomson jack',
#  'application configure request change or edit the application perform weekly srm hr replication',
#  'data shopping cart shopping cart error run change po job manually',
#  'data issue incorrect data in backend please post revised customer scripts',
#  'general request general service request starters leavers ',
#  'access request access modification sap access request form – attention required – request form for applicant singh gaurav kumar',
#  'access missing time tracker complete estimate',
#  'data request data report sap invoice reports request',
#  'data mismatch records missing in table repush idocs for testing in ',
#  'access request access modification sap access request form – attention required – request form for applicant kumar madhu',
#  'access request access modification sap access request form – attention required – request form for applicant pothani shiresh kumar',
#  'access request access modification sap access request form – attention required – request form for applicant seetharaman vasanthan',
#  'data missing field missing in documents  error for po  tp techus',
#  'application code bug fix dm not linked to dispute cases',
#  'access issue unable to access application maccs slowness',
#  'jobprocess schedule  run jobs  backups  ers extraction',
#  'data request data update request create new studio  participation label named pretty picture in sap for french territory ',
#  'request estimate enhancement csv fo creator upgrade to access  estimate',
#  'request enquiry information transaction codes',
#  'access request access modification sap access request form – attention required – request form for applicant belgrave natasha',
#  'access request access modification urgent  complete request  general service request',
#  'access issue unable to access application  in bo request for bo user account creation  moh',
#  'general request estimate complete estimate ',
#  'request estimate enhancement complete estimate ',
#  'request estimate enhancement dtd contracts db upgrade to access ',
#  'request estimate enhancement dtd turner db upgrade to access ',
#  'request estimate enhancement csv fo creator security changes',
#  'application performance issue portal cache refresh in cmd system',
#  'report request report run retrieve lead time information for list of stores',
#  'request enquiry information smart batch etl monitoring',
#  'access issue unable to access environment  reset password',
#  'access issue unable to access application wb account offboarding request sap  xhprabha',
#  'access issue unable to access application wb account offboarding request sap',
#  'report request report run nr in stock report by facing  extract request for today at  am ist and  pm ist',
#  'access request account creation cmp password reset ',
#  'batch job request monthly dtd invoice printing cmp dtd invoice printing for ',
#  'access approval  accesssap issueunable to access environment access key required for routine  in dev',
#  'access issue unable to access environment  plm process chain monitoring for week  to ',
#  'application monitoring healthcheck plm portal health check for week  to ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'general request general service request archivign fds preparation',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'access approval  accesssap issueunable to access environment background jobs in quality not getting processed',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'general request general service request amer ods  mdm load ',
#  'general request general service request gems ods  mdm load ',
#  'general request general service request gems ods  mdm load ',
#  'general request general service request amer  ods  mdm load ',
#  'general request general service request gems  ods  mdm load',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'application monitoring healthcheck   errors in scp clearing cif stuck queues  on ',
#  'data request data update request new charge code request',
#  'access request unlock flash  forecast  delete  data',
#  'serverservicewebsite connection issue services are down bwp system monitoring from  to ',
#  'delete data deletion as per user requirement flash  please copy       asap',
#  'data request data update request daily idocs monitoring carried out on   ',
#  'serverservicewebsite connection issue services are down bwp broadcast job monitoring from  to ',
#  'access approval  accesssap issueunable to access environment frb recon on ',
#  'data missing issue corp recon on ',
#  'access issue unable to access environment  need temporary password for emergency access raised for id exdbhiman',
#  'access issue unable to access environment   portal upgrade testing  no flash tab',
#  'application monitoring healthcheck monitoring services  great plains ar',
#  'request enquiry information duplicate error message screenshot attached',
#  'service request service requestanalysis  error appears while coding the invoice',
#  'access issue unable to access environment  please create test id in    system for user id uknair same as bwp   systems',
#  'application monitoring healthcheck bdocs monitoring for period  to ',
#  'application monitoring healthcheck batch jobs monitoring for period  to ',
#  'application monitoring healthcheck tdm batch jobs monitoring for period  to ',
#  'application monitoring healthcheck ip mismatch report for period  to ',
#  'application monitoring healthcheck batch job monitoring for zipmrelresupdate for period  to ',
#  'application monitoring healthcheck bdocs monitoring for  to ',
#  'application monitoring healthcheck batch jobs monitoring for period  to ',
#  'access request access modification sap password reset',
#  'report request report run rim online   main screen  switzerland vmi support',
#  'batch job load issue job monitoring daily bcs monitoring for actuals  plan   ',
#  'batch job load issue job monitoring daily bcs monitoring for actuals  plan   ',
#  'batch job load issue job monitoring daily bcs monitoring for actuals  plan   ',
#  'batch job load issue job monitoring daily bcs monitoring for actuals  plan   ',
#  'batch job load issue job monitoring daily bcs monitoring for actuals  plan   ',
#  'access issue unable to access application wb  coe  has difference in maccs vs sap reconciliation for germany in revenue part for dated ',
#  'data transmission issue trasmission not appearing in target system daily idocs reconciliation carried out on    ',
#  'access request account creation lost sap access',
#  'access issue unable to access application urgent  complete request  sap system open access process',
#  'access issue unable to access application tobi user favorite report is not working ',
#  'access approval  accesssap issueunable to access environment complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant jiang tina',
#  'data request data update request    outbound  idocs  status  debmas ',
#  'application monitoring healthcheck rimusa monitoring replen runsorders wc from  to ',
#  'access issue unable to access application tobi user scheduled  favorites reports are not working as expected ',
#  'jobprocess schedule  run jobs  backups rimbn count files media t nl be',
#  'application monitoring healthcheck health rimusa monitoring jobsdata loadsalertsqueue wc from  to ',
#  'application monitoring healthcheck rimemea monitor jobsqueuesalertsorders for all emea territories wc from  to ',
#  'access request add mac address account request',
#  'access request access modification   sap access request ',
#  'authorization request user request to grant access   sap access request ',
#  'access issue unable to access environment  addcess access in  simiar to  portal for xnreddy',
#  'request estimate enhancement estimate  output determination routine',
#  'access request access modification    sap access request form – attention required – request form for applicant okane conor',
# ...
#  'data mismatch duplicate entry flash create ',
#  'access request access modification sap access request form – attention required – request form for applicant thomas virginia',
#  'access issue unable to access application wb account offboarding request sap',
#  'access issue unable to access application wb account offboarding request sap',
#  'access issue unable to access application wb account offboarding request sap',
#  'access issue unable to access application wb account offboarding request sap',
#  'access issue unable to access application wb account offboarding request sap',
#  'access issue unable to access application  portal cache refresh',
#  'access request access modification userid replication for dpl issue',
#  'request enquiry information complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant bradley lyn',
#  'access request new access need wpd restarted to fix ldap rfc connection',
#  'data transmission issue incorrect status orders to bertelsmann inc in status ',
#  'service request upload data map title to deal split id  in updoc',
#  'access issue unable to access environment  oss connection for ',
#  'application windows  regression testing windows  regression testing in ',
#  'application windows  regression testing windows  regression testing in ',
#  'application batch job failure provide access key in srm system',
#  'service request info request vendor number',
#  'general request general service request daily idocs monitoring carried out on   ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'data mismatch records missing in table cosmos fca sub item sweep for the week from  to ',
#  'request enquiry information cosmos fca sub item sweep fix for the deals listed in fca sweep ran for ',
#  'access issue unable to access environment  cosmos itd and dtd reconciliation for ',
#  'data mismatch data reconciliation daily idocs reconciliation carried out on    ',
#  'request enquiry information cosmos inactive deal processing financially irrelevant deals load on ',
#  'general request general service request amer ods  mdm load for ',
#  'access issue unable to access environment  frb recon on ',
#  'application interface issue corp recon on ',
#  'general request general service request gems  ods  mdm load for ',
#  'general request general service request urgent questions from wbj regarding sap approval chain',
#  'data incorrect value printing issue urgent  complete request  general service request',
#  'access request access modification   reset password for gui crm cmp system for user xngholap',
#  'data missing field missing in documents isa  reported in extract report is not generated output',
#  'access request new access   urgent  complete request  change or configure an application',
#  'access request access modification urgent  complete request  general service request',
#  'access request access modification   please reset the password for xmnainar in  system',
#  'authorization request user request to grant access open  httpgui connection for sap oss inc',
#  'access issue unable to access environment   role to be extended for project and support resources for ongoing production support',
#  'access issue unable to access application prod to dev migration request',
#  'data missing field missing in documents   outbound  idocs  status  debmas  ordrsp',
#  'access issue unable to access application  migrate the wmdf report',
#  'access request access modification   complete request  general service request',
#  'service request patch upgrade stars vulnerabilities',
#  'application issue not accessable invoice link not working',
#  'data incorrect value delete data push material to ldx',
#  'data validation validation failed complete request  general service request',
#  'access issue unable to access application we have planned migration activity on   pm pst to  pm pst need to migrate dwf universe and reports from  to prod',
#  'application monitoring healthcheck   errors in scp clearing cif stuck queues  on ',
#  'access issue unable to access application please add new mdh user so that he can access the scripts posted on the home page of the mdh site',
#  'access request account creation  sap prd company code',
#  'application monitoring healthcheck rimch  stock file monitoring for mediamarkt switzerland',
#  'authorization request user request to grant access   non prod access for below domain ids in  bw and bh boxes for xzfeza xvzsingh xvsharma',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'batch job load issue job monitoring batch job monitoring  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'request enquiry information monthly close activities for  ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'access issue unable to access application unable to run abstract report in ',
#  'report daily activity daily report creation report sony and technicolor  ',
#  'access request new access request for open up   and http connections in  system',
#  'request enquiry information sap modification',
#  'access request access modification sap access request form – attention required – request form for applicant tucker kimberleigh',
#  'access request access modification   sap access request form – attention required – request form for applicant appelberg helene',
#  'batch job modification deletion of batch jobs sap cancel pssr job for benelux and add sales org   to pssr france',
#  'access approval  accesssap issueunable to access environment changes not moved to ',
#  'request enquiry information  lift validation',
#  'access request provide access add user bu coder rights',
#  'configuration request feed new tax codee request',
#  'access issue unable to access application poland theaters  tobicms feed from maccs',
#  'request estimate enhancement estimate request  ldx due date and document date',
#  'request estimate enhancement sizing estimate request for bcs plan copy automation',
#  'application configure request change or edit the application accountingdunning clerk adjustment',
#  'request enquiry information urgent  not authorized to use transaction zpickhier in flash lp frb picklist',
#  'application configure request change or edit the application item stuck in ',
#  'data mismatch incorrect data found  order',
#  'data mismatch incorrect data found  issue has already been posted',
#  'access request unlock bdoc reprocess in cmp',
#  'request enquiry information gcac  by title reconciliation ',
#  'upload failure bad file  company code    interface not done ',
#  'request enquiry information gcac   reconciliation ',
#  'request enquiry information gcac   reconciliation ',
#  'access issue unable to access application sap prd extension request',
#  'upload failure bad file  company code   and     interface not done ',
#  'access request access modification sap access request form – attention required – request form for applicant sitnik katarzyna',
#  'request enquiry information bpc monitoring activities',
#  'report request report run extraction',
#  'upload failure bad file  interface issue',
#  'access request access modification   sap access request form – attention required – request form for applicant denisova yelena',
#  'access request remove access    sap account disable',
#  'access request account creation rfc authorization issues in xrp',
#  'access request access modification complete request  general service request qvc handover',
#  'workflow issue workflow issue process the purchase order that needed to be coded to a vendor',
#  'report daily activity daily report creation inbound error report ',
#  'report weekly activity report creation recon tool upload details ',
#  'data mismatch price mismatch walmart canada sbt orders from silkroutca in status  due to pricing',
#  'authorization request user request to grant access   access to user xasaxena in cmd hana system',
#  'access request access modification sap access request form – attention required – request form for applicant wu kari',
#  'access request access modification sap access request form – attention required – request form for applicant thomson jack',
#  'general request general service request urgent  complete request  general service request',
#  'general request general service request process pma list attached mail contains details',
#  'access request account creation urgent  complete request  install new phone phone line or data line',
#  'data transmission issue trasmission not appearing in target system resend best buy us xml file for  to srg',
#  'access request access modification sap access request form – attention required – request form for applicant robertson benjamin',
#  'access request access modification sap access request form – attention required – request form for applicant kwan joyce',
#  'access request new access mdh new user request email sent for login id please see attached and follow up',
#  'access request access modification sap access request form – attention required – request form for applicant walker e',
#  'application configure request change or edit the application urgent inymbus email update for customer  arvato de mexico sa de cv',
#  'request enquiry information tlsv informatica server confiog for cosmos interfaces',
#  'application code bug fix complete request  general service request',
#  'access issue unable to access application ',
#  'access request access modification sap access request form – attention required – request form for applicant ecumbi fernando',
#  'access request access modification sap access request form – attention required – request form for applicant bukkapatnam uday kiran',
#  'access request access modification sap access request form – attention required – request form for applicant ahmed jawad',
#  'data mismatch incorrect data found bby us xml  pos file sent to in on ',
#  'data incorrect value invoice not getting created urgent fico interface incorrect billing date',
#  'data transmission issue trasmission not appearing in target system ingram invoic not received attached list for details',
#  'access issue unable to access application sapbo user access request for xsshank',
#  'general request general service request bpo ',
#  'access issue unable to access environment  sap access extension',
#  'access request account creation  account validity update for xssrey',
#  'access approval  accesssap issueunable to access environment web service zcasudhbwebsercoupdocholport is not working in ',
#  'application issue not accessable urgent  complete request  general service request',
#  'access request account creation sap prd password reset',
#  'access issue unable to access application migrate report    ltd actuals vs ultimates  estimates from prod to dev',
#  'request enquiry information sap account numbers request',
#  'access request new access license request',
#  'access issue unable to access application migrate report   ltd actuals vs ultimates  estimates from devqaprod',
#  'access request access modification sap password reset',
#  'data request data update request complete request  general service request',
#  'access issue unable to access application extended expiration date',
#  'access request access modification    sap password reset',
#  'data mismatch incorrect data found best buy us pos in in for  be overstated',
#  'access request access modification sap access request form – attention required – request form for applicant pfeisinger milan',
#  'access sap issue unable to access environment  solman sop  cclm  mmissioning  igs error and short dumps  needs permanent fix  see attached',
#  'request enquiry information requesting all billing condition types for tax used in sap',
#  'access request access modification sap access request form – attention required – request form for applicant naduvinmani vani sudheer',
#  'data mismatch records missing in table salesforce is receiving idocs for  and  ',
#  'data request data report complete estimate',
#  'data request data update request complete request  general service request',
#  'access request access modification sap access request form – attention required – request form for applicant valdez samuel',
#  'access request access modification sap access request form – attention required – request form for applicant bhagavathula vss chandra',
#  'request enquiry information complete request  general service request',
#  'access request new access access to updoc for belkys rojas',
#  'data transmission issue email not being sent srm approver not receiving email notifications',
#  'access request add mac address manually adding mac addresses',
#  'application co report issue   new looney tunes ii  appears twice with the error no release windows',
#  'workflow issue approval hierarchy issue sla approver confirmation',
#  'access approval  accesssap issueunable to access environment ultimates bu submission work book issue in ',
#  'request enquiry information need sap purchase reports for the month of starting from  to ',
#  'request enquiry information  sap issue',
#  'request enquiry information unable to enter doc date and total amount',
#  'access issue unable to access environment  frb recon on ',
#  'data mismatch incorrect data found urgent  complete request  general service request',
#  'application interface issue corp recon on ',
#  'workflow issue workflowmail notification error invoice can not recall to index',
#  'application monitoring idocs daily idocs monitoring carried out on    ',
#  'data mismatch data reconciliation bol  \xa0 nl  bolcom bv  aic audit',
#  'application configure request change or edit the application sap credit memo approval path testing',
#  'data mismatch data reconciliation carrefour belgium    becarrefour belgium s a  aic audit',
#  'data missing field missing in documents   outbound  idocs  status  ordrsp   ',
#  'serverservicewebsite connection issue services are down please provide details of user id xtvu whether this user id is active or not',
#  'access issue unable to access application odsbr got failed',
#  'service request testing  validation updoc win  application testing',
#  'service request testing  validation vulnerability remediation testing  jaco',
#  'application monitoring healthcheck delete the slh logs from slhub dev qa  prd servers',
#  'application monitoring healthcheck daily monitoring file process and healthcheck for the  slhub application for week   ',
#  'application monitoring healthcheck daily monitoring file process and healthcheck for the  fringeengine application for week  ',
#  'access issue unable to access application urgent  complete request  general service request',
#  'application monitoring healthcheck gp file process and weekly filetwiddept process',
#  'access issue unable to access application complete request  general service request',
#  'access approval  accesssap issueunable to access environment create sid for user xishah',
#  'request enquiry information owning comp code repost  manual activity    ',
#  'application services down complete request  general service request',
#  'data data flow data flow failure   qvc  business technology  workplace solutions btws',
#  'authorization issue maintain table entry maintain the zparams and zoemailid in prd',
#  'access issue unable to access environment  report broadcasting for period close   ',
#  'serverservicewebsite connection issue services are down please correct user records asap',
#  'access request access modification   unable to change the password for sap prd',
#  'access issue unable to access application dev to  migration request',
#  'access issue unable to access application migrate the sap wmdf report',
#  'request enquiry information bpc monitoring activities',
#  'data mismatch data reconciliation daily idocs reconciliation carried out on   ',
#  'access request account creation unable to raise emergency access in portal',
#  ...]

# %%
# %%time
sentences = cleaned_sentences
sentence_words = [[word for word in sent.split()]
                  for sent in sentences]

filtered_words = [[w for w in lst if len(w) > 2] for lst in sentence_words]         
                  
print(filtered_words)

                  
# [[w for w in lst if len(w) > 2] for lst in wordsx]                  
# print [[item for item in clist if len(item) >= 3] for clist in lists]
# Out:
# [['access', 'issue', 'unable', 'access', 'application', 'user', 'cannot', 'access', 'timeoff', 'tracker'], ['delete', 'data', 'deletion', 'per', 'user', 'requirement', 'deal', 'status', 'payment', 'progress', 'with', 'payment'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'error', 'messge', 'stating', 'that', 'the', 'alternate', 'payee', 'group', 'does', 'not', 'exist'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'frb', 'reconciliation', 'need', 'perform'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'urgent', 'forward', 'eform', 'another', 'approver'], ['request', 'enquiry', 'information', 'report', 'migration', 'from', 'dev'], ['access', 'request', 'unlock', 'disable', 'batch', 'jobs'], ['access', 'request', 'unlock', 'complete', 'request', 'general', 'service', 'request'], ['access', 'request', 'remove', 'access', 'hpqc', 'access', 'project', 'workday', 'domain', 'mis', 'xvdhake'], ['access', 'issue', 'unable', 'access', 'environment', 'help', 'withsetting', 'cbs', 'profile', 'wbconnect'], ['access', 'request', 'unlock', 'route', 'ticket', 'new', 'approver'], ['access', 'request', 'unlock', 'proactive', 'breakfix', 'incident', 'ticket', 'for', 'monthly', 'release', 'into', 'production'], ['access', 'issue', 'unable', 'access', 'environment', 'add', 'approver', 'hierarchy'], ['data', 'request', 'quantity', 'change', 'change', 'order', 'cbs'], ['access', 'issue', 'unable', 'access', 'environment', 'substitute', 'approver'], ['access', 'request', 'unlock', 'need', 'configure', 'drivers', 'order', 'refresh', 'lumira', 'launchpad'], ['access', 'request', 'unlock', 'assistance', 'with', 'filling', 'out'], ['access', 'request', 'unlock', 'proactive', 'emergency', 'breakfix', 'incident', 'ticket', 'for', 'monthly', 'release', 'into', 'production'], ['access', 'request', 'add', 'email', 'eform'], ['application', 'batch', 'job', 'failure', 'list', 'people', 'who', 'have', 'role', 'for', 'company', 'code'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'complete', 'request', 'general', 'service', 'request'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'please', 'migrate', 'the', 'objects', 'from'], ['data', 'shopping', 'cart', 'shopping', 'cart', 'error', 'master', 'ticket', 'for', 'srm', 'change', 'order', 'issues'], ['data', 'request', 'data', 'update', 'request', 'modify', 'riverbed', 'settings', 'support', 'teradata', 'data', 'migration', 'per', 'bobby', 'paik'], ['access', 'request', 'unlock', 'urgent', 'complete', 'request', 'general', 'service', 'request'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'error', 'when', 'trying', 'log'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'request', 'for', 'new', 'sharepoint', 'path'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'adobe', 'eforms', 'attention', 'required', 'eform', 'request', 'form', 'for', 'applicant', 'matthew', 'leos'], ['invalid', 'request', 'error', 'found', 'big', 'sap', 'edit', 'error', 'needs', 'assistance', 'how', 'clear', 'these', 'labor', 'errors'], ['data', 'data', 'flow', 'data', 'flow', 'failure', 'tpx', 'gen', 'transmissions'], ['general', 'request', 'general', 'service', 'request', 'remediation', 'items', 'for', 'treasury', 'hedging', 'database'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'get', 'operative', 'one', 'configuration', 'informations'], ['access', 'approval', 'accesssap', 'issueunable', 'access', 'environment', 'clscritical', 'transmission'], ['request', 'enquiry', 'information', 'update', 'property', 'department', 'website', 'front', 'page'], ['application', 'upgrade', 'new', 'version', 'maccs', 'germany', 'cannot', 'save', 'the', 'vat', 'report', 'pdf'], ['request', 'enquiry', 'information', 'lift', 'the', 'validation', 'for', 'accounts'], ['request', 'enquiry ...
# Wall time: 41 ms

# %%
# %%time
# Creating gensim word2vec model
import multiprocessing
from gensim.models import Word2Vec

# Count no. of cores in computer
cores = multiprocessing.cpu_count()

# Model parameters
wb_word2vec_model = Word2Vec(min_count=5,
                            window=5,
                            size=300,
                            sample=6e-5,
                            alpha=0.03,
                            min_alpha=0.0007,
                            negative=20,
                            workers=cores-1)


print(wb_word2vec_model)
# Out:
# Word2Vec(vocab=0, size=300, alpha=0.03)
# Wall time: 998 µs

# %%
# %%time
# Build vacoubalry
wb_word2vec_model.build_vocab(filtered_words)


print(wb_word2vec_model)
# Out:
# Word2Vec(vocab=773, size=300, alpha=0.03)
# Wall time: 243 ms

# %%
# %%time
# Training the model
wb_word2vec_model.train(filtered_words, total_examples=wb_word2vec_model.corpus_count, epochs=30)
# Out:
# Wall time: 1.15 s
# (263123, 1586940)

# %%
# summarize vocabulary
words = list(wb_word2vec_model.wv.vocab)
print(words)
# Out:
# ['access', 'issue', 'unable', 'application', 'user', 'cannot', 'delete', 'data', 'deletion', 'per', 'requirement', 'deal', 'status', 'payment', 'with', 'approval', 'accesssap', 'issueunable', 'environment', 'error', 'that', 'the', 'group', 'does', 'not', 'frb', 'reconciliation', 'need', 'perform', 'urgent', 'eform', 'approver', 'request', 'enquiry', 'information', 'report', 'migration', 'from', 'dev', 'unlock', 'batch', 'jobs', 'complete', 'general', 'service', 'remove', 'project', 'workday', 'domain', 'help', 'cbs', 'profile', 'wbconnect', 'ticket', 'new', 'incident', 'for', 'monthly', 'release', 'into', 'production', 'add', 'hierarchy', 'quantity', 'change', 'order', 'configure', 'refresh', 'out', 'emergency', 'email', 'job', 'failure', 'list', 'have', 'role', 'company', 'code', 'please', 'migrate', 'objects', 'shopping', 'cart', 'master', 'srm', 'issues', 'update', 'modify', 'support', 'when', 'log', 'adobe', 'attention', 'required', 'form', 'applicant', 'invalid', 'found', 'sap', 'edit', 'needs', 'how', 'these', 'errors', 'flow', 'transmissions', 'remediation', 'items', 'hedging', 'database', 'get', 'one', 'configuration', 'clscritical', 'transmission', 'page', 'upgrade', 'version', 'maccs', 'germany', 'save', 'pdf', 'lift', 'validation', 'accounts', 'buffer', 'table', 'related', 'billing', 'inymbus', 'cases', 'portal', 'analysis', 'bachelor', 'and', 'account', 'creation', 'failed', 'cmp', 'serverservicewebsite', 'connection', 'services', 'are', 'down', 'maintain', 'business', 'psl', 'exception', 'series', 'process', 'cosmos', 'line', 'modification', 'extend', 'mpm', 'sales', 'scheduling', 'manual', 'run', 'transaction', 'posted', 'destination', 'system', 'vendor', 'showing', 'open', 'wbei', 'trasmission', 'appearing', 'target', 'investigate', 'recon', 'tool', 'sox', 'audit', 'revaluation', 'currency', 'correctly', 'create', 'idoc', 'invoice', 'wrong', 'number', 'titles', 'flash', 'ultimates', 'incorrect', 'all', 'software', 'vendors', 'include', 'tax', 'amount', 'mismatch', 'records', 'missing', 'following', 'episode', 'duplicate', 'entry', 'current', 'sylvester', 'tab', 'participations', 'estimate', 'tables', 'systems', 'can', 'you', 'let', 'know', 'details', 'studionet', 'activity', 'against', 'monitoring', 'utility', 'program', 'crmdcustomeri', 'sync', 'test', 'testing', 'plant', 'bug', 'fix', 'close', 'values', 'has', 'been', 'regarding', 'enhancement', 'send', 'only', 'territory', 'holdbacks', 'time', 'mapping', 'transfer', 'requests', 'requested', 'difference', 'set', 'adding', 'tdm', 'cost', 'pds', 'config', 'attached', 'web', 'bds', 'hub', 'alert', 'network', 'servers', 'team', 'password', 'reset', 'great', 'plains', 'object', 'removed', 'roles', 'basis', 'charm', 'being', 'two', 'updates', 'field', 'documents', 'effort', 'rim', 'carrefour', 'france', 'item', 'profit', 'center', 'bdoc', 'reporting', 'week', 'mdh', 'stars', 'season', 'admin', 'healthcheck', 'slhub', 'performance', 'archival', 'backuprestore', 'load', 'brazil', 'bookings', 'license', 'notification', 'confirm', 'your', 'server', 'file', 'excel', 'screen', 'see', 'tobi', 'install', 'amazon', 'aic', 'grant', 'leavesden', 'message', 'needed', 'dates', 'created', 'review', 'provide', 'this', 'owning', 'repost', 'scenario', 'customer', 'schedule', 'cleansing', 'changes', 'windows', 'dtd', 'printing', 'date', 'interfaced', 'ipm', 'edi', 'invoices', 'question', 'spain', 'prd', 'after', 'plm', 'location', 'type', 'plan', 'actuals', 'reports', 'inclusion', 'check', 'codes', 'cancellation', 'cancel', 'below', 'scope', 'failing', 'post', 'ers', 'actual', 'year', 'housley', 'torree', 'rimca', 'bby', 'bhd', 'but', 'authorization', 'while', 'accessable', 'users', 'able', 'work', 'emails', 'received', 'dumps', 'runtime', 'kumar', 'bank', 'stuck', 'reason', 'outbound', 'idocs', 'debmas', 'backend', 'security', 'trace', 'dump', 'pack', 'product', 'discrepancy', 'than', 'there', 'walmart', 'unit', 'maintenance', 'script', 'working', 'balance', 'purchase', 'leavers', ' ...

# %%
# %%time
# Save word2vec model
wb_word2vec_model.save("./wb_word2vec_model.model")

# Save WV
wb_word2vec_model.wv.save_word2vec_format("wb_word2vec_model.txt")
# Out:
# Wall time: 224 ms

# %%
# %%time
# Load the custom wb_word2vec_model 

wb_word2vec_model = gensim.models.KeyedVectors.load_word2vec_format("./wb_word2vec_model.txt", binary = False)
print("wb_word2vec_model")
# Out:
# wb_word2vec_model
# Wall time: 346 ms

# %%
# %%time
# Create BOW
# Create corpora
from gensim import corpora


dictionary = corpora.Dictionary(filtered_words)

# Creating BOW

bow_corpus = [dictionary.doc2bow(word) for word in filtered_words]
for sent,embedding in zip(cleaned_sentences,bow_corpus):
    print(sent)
    print(embedding)
# Out:
# access issue unable to access application user cannot access timeoff tracker
# [(0, 3), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1)]
# delete data deletion as per user requirement   deal status payment in progress with no payment
# [(7, 1), (8, 1), (9, 1), (10, 1), (11, 1), (12, 2), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1)]
# access approval  accesssap issueunable to access environment error messge stating that the alternate payee group does not exist
# [(0, 2), (18, 1), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1)]
# access approval  accesssap issueunable to access environment frb reconciliation need to be perform on
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (33, 1), (34, 1), (35, 1), (36, 1)]
# access approval  accesssap issueunable to access environment  urgent forward eform  to another approver
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1)]
# request enquiry information report migration from dev to qa
# [(42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1)]
# access request unlock disable ei batch jobs
# [(0, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1)]
# access request unlock complete request  general service request
# [(0, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# access request remove access hpqc access to project workday domain mis  id xvdhake
# [(0, 3), (48, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1)]
# access issue unable to access environment  help withsetting up cbs profile in wbconnect
# [(0, 2), (3, 1), (6, 1), (22, 1), (63, 1), (64, 1), (65, 1), (66, 1), (67, 1)]
# access request unlock route ticket to new approver
# [(0, 1), (38, 1), (48, 1), (52, 1), (68, 1), (69, 1), (70, 1)]
# access request unlock proactive breakfix  incident ticket for  monthly release into production
# [(0, 1), (48, 1), (52, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1)]
# access issue unable to access environment  add an approver to hierarchy
# [(0, 2), (3, 1), (6, 1), (22, 1), (38, 1), (79, 1), (80, 1)]
# data request quantity change change order in cbs
# [(8, 1), (48, 1), (63, 1), (81, 2), (82, 1), (83, 1)]
# access issue unable to access environment  substitute approver
# [(0, 2), (3, 1), (6, 1), (22, 1), (38, 1), (84, 1)]
# access request unlock need  to configure drivers in order to refresh lumira on bi launchpad
# [(0, 1), (34, 1), (48, 1), (52, 1), (82, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1)]
# access request unlock  assistance with filling out
# [(0, 1), (17, 1), (48, 1), (52, 1), (90, 1), (91, 1), (92, 1)]
# access request unlock proactive emergency breakfix  incident ticket for   monthly release into production
# [(0, 1), (48, 1), (52, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (93, 1)]
# access request add email id eform
# [(0, 1), (39, 1), (48, 1), (79, 1), (94, 1)]
# application batch job failure list of people who have role for company code
# [(1, 1), (49, 1), (72, 1), (95, 1), (96, 1), (97, 1), (98, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1)]
# access approval  accesssap issueunable to access environment complete request  general service request
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (48, 2), (53, 1), (54, 1), (55, 1)]
# access approval  accesssap issueunable to access environment please migrate the bo objects from  to
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (32, 1), (44, 1), (104, 1), (105, 1), (106, 1)]
# data shopping cart shopping cart error master ticket for srm change order issues
# [(8, 1), (23, 1), (70, 1), (72, 1), (81, 1), (82, 1), (107, 2), (108, 1), (109, 1), (110, 2), (111, 1)]
# data request data update request modify riverbed settings to support teradata data migration per bobby paik
# [(8, 3), (13, 1), (46, 1), (48, 2), (112, 1), (113, 1), (114, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 1)]
# access request unlock urgent  complete request  general service request
# [(0, 1), (41, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# access approval  accesssap issueunable to access environment error when trying to log in to
# [(0, 2), (18, 1), (20, 1), (22, 1), (23, 1), (26, 1), (120, 1), (121, 1), (122, 1)]
# access approval  accesssap issueunable to access environment request for new sharepoint path
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (48, 1), (68, 1), (72, 1), (123, 1), (124, 1)]
# access approval  accesssap issueunable to access environment adobe eforms  attention required  eform  request form for applicant matthew leos
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (39, 1), (48, 1), (72, 1), (125, 1), (126, 1), (127, 1), (128, 1), (129, 1), (130, 1), (131, 1), (132, 1)]
# invalid request error found big  sap edit error  needs assistance on how to clear these labor errors
# [(23, 2), (48, 1), (90, 1), (133, 1), (134, 1), (135, 1), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1), (142, 1), (143, 1)]
# data data flow data flow failure tpx gen  transmissions
# [(8, 3), (97, 1), (144, 2), (145, 1), (146, 1), (147, 1)]
# general request general service request remediation items for treasury hedging database
# [(48, 2), (54, 2), (55, 1), (72, 1), (148, 1), (149, 1), (150, 1), (151, 1), (152, 1)]
# access approval  accesssap issueunable to access environment to get operative one configuration informations
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (153, 1), (154, 1), (155, 1), (156, 1), (157, 1)]
# access approval  accesssap issueunable to access environment clscritical transmission
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (158, 1), (159, 1)]
# request enquiry information update to wb property department website front page
# [(43, 1), (45, 1), (48, 1), (119, 1), (160, 1), (161, 1), (162, 1), (163, 1), (164, 1)]
# application upgrade new version maccs germany  i cannot save the  vat report in pdf
# [(1, 1), (2, 1), (32, 1), (47, 1), (68, 1), (165, 1), (166, 1), (167, 1), (168, 1), (169, 1), (170, 1), (171, 1)]
# request enquiry information  lift the validation for gl accounts
# [(32, 1), (43, 1), (45, 1), (48, 1), (72, 1), (172, 1), (173, 1), (174, 1)]
# request enquiry information master ticket for buffer table related issues
# [(43, 1), (45, 1), (48, 1), (70, 1), (72, 1), (108, 1), (109, 1), (175, 1), (176, 1), (177, 1)]
# application issue billing issue inymbus issue  cases on deniedwb status that need to be resubmitted to wm portal
# [(1, 1), (3, 3), (16, 1), (31, 1), (34, 1), (178, 1), (179, 1), (180, 1), (181, 1), (182, 1), (183, 1)]
# request enquiry analysis  bachelor  exceptions   and
# [(43, 1), (48, 1), (184, 1), (185, 1), (186, 1), (187, 1)]
# access request account creation jobs failed in cmp
# [(0, 1), (48, 1), (51, 1), (188, 1), (189, 1), (190, 1), (191, 1)]
# serverservicewebsite connection issue services are down please maintain relationship for business partner  hiroki tanzawa
# [(3, 1), (72, 1), (106, 1), (192, 1), (193, 1), (194, 1), (195, 1), (196, 1), (197, 1), (198, 1), (199, 1), (200, 1), (201, 1), (202, 1)]
# access issue unable to access application please help resolve psl exception report for ellen  series
# [(0, 2), (1, 1), (3, 1), (6, 1), (47, 1), (64, 1), (72, 1), (106, 1), (203, 1), (204, 1), (205, 1), (206, 1), (207, 1)]
# access issue unable to access environment  process the deal  from ps to
# [(0, 2), (3, 1), (6, 1), (9, 1), (22, 1), (32, 1), (44, 1), (208, 1)]
# access issue unable to access environment  process cosmos deal bp master and bp relations for deal line
# [(0, 2), (3, 1), (6, 1), (9, 2), (22, 1), (72, 1), (109, 1), (185, 1), (208, 1), (209, 1), (210, 1), (211, 1)]
# access request access modification sap crm adobe eforms  attention required  eform  request form for applicant leo mylonadis
# [(0, 2), (39, 1), (48, 2), (72, 1), (125, 1), (126, 1), (127, 1), (128, 1), (129, 1), (132, 1), (142, 1), (212, 1), (213, 1), (214, 1), (215, 1)]
# request enquiry information extend mpm s  and  to intl tv cosmos sales orgs
# [(43, 1), (45, 1), (48, 1), (185, 1), (209, 1), (216, 1), (217, 1), (218, 1), (219, 1), (220, 1)]
# request enquiry information report scheduling to sharepoint
# [(43, 1), (45, 1), (47, 1), (48, 1), (124, 1), (221, 1)]
# general request general service request manual run for blindspot   cast payment
# [(12, 1), (48, 2), (54, 2), (55, 1), (72, 1), (222, 1), (223, 1), (224, 1), (225, 1)]
# data transaction issue transaction not posted in destination system vendor showing as open is ed for deletion
# [(3, 1), (8, 1), (11, 1), (28, 1), (72, 1), (226, 1), (227, 1), (228, 1), (229, 1), (230, 1), (231, 2), (232, 1)]
# access request account creation please help resolve psl exception report for ellen
# [(0, 1), (47, 1), (48, 1), (64, 1), (72, 1), (106, 1), (188, 1), (190, 1), (203, 1), (204, 1), (205, 1), (206, 1)]
# access issue unable to access application wbei outage initial notice
# [(0, 2), (1, 1), (3, 1), (6, 1), (233, 1), (234, 1), (235, 1), (236, 1)]
# access request unlock please change pw for tmsadm in  sapcpic in   and sap in
# [(0, 1), (48, 1), (52, 1), (72, 1), (81, 1), (106, 1), (142, 1), (185, 1), (237, 1), (238, 1)]
# data transmission issue trasmission not appearing in target system please investigate exceptions on project mix psl exception report
# [(3, 1), (8, 1), (28, 1), (47, 1), (59, 1), (106, 1), (159, 1), (187, 1), (204, 1), (205, 1), (230, 1), (239, 1), (240, 1), (241, 1), (242, 1), (243, 1)]
# request enquiry information data recon tool issues for blindspot  series
# [(8, 1), (43, 1), (45, 1), (48, 1), (72, 1), (108, 1), (207, 1), (222, 1), (244, 1), (245, 1)]
# request enquiry information data recon tool issues for horizon alternative
# [(8, 1), (43, 1), (45, 1), (48, 1), (72, 1), (108, 1), (244, 1), (245, 1), (246, 1), (247, 1)]
# request enquiry information data recon tool issues for snu project
# [(8, 1), (43, 1), (45, 1), (48, 1), (59, 1), (72, 1), (108, 1), (244, 1), (245, 1), (248, 1)]
# access sap issue unable to access environment  requirement for sox audit
# [(0, 2), (3, 1), (6, 1), (15, 1), (22, 1), (72, 1), (142, 1), (249, 1), (250, 1)]
# access issue unable to access environment  adobe eforms  attention required  eform  request form for applicant man chan
# [(0, 2), (3, 1), (6, 1), (22, 1), (39, 1), (48, 1), (72, 1), (125, 1), (126, 1), (127, 1), (128, 1), (129, 1), (132, 1), (251, 1), (252, 1)]
# data transmission issue trasmission not appearing in target system tmz   new exception report
# [(3, 1), (8, 1), (28, 1), (47, 1), (68, 1), (159, 1), (204, 1), (230, 1), (239, 1), (242, 1), (243, 1), (253, 1)]
# request enquiry information clscritical revaluation posted in co code  for transaction currency eur isnt correctly calculated
# [(43, 1), (45, 1), (48, 1), (72, 1), (95, 1), (158, 1), (228, 1), (231, 1), (254, 1), (255, 1), (256, 1), (257, 1), (258, 1), (259, 1)]
# access request access modification create the deal  idoc into
# [(0, 2), (9, 1), (32, 1), (48, 1), (74, 1), (214, 1), (260, 1), (261, 1)]
# request enquiry information invoice issue  wrong vat number
# [(3, 1), (43, 1), (45, 1), (48, 1), (170, 1), (262, 1), (263, 1), (264, 1)]
# general request general service request newly included languages not flown to nts and titles not flowing down to nts
# [(28, 2), (48, 2), (54, 2), (55, 1), (185, 1), (195, 1), (265, 1), (266, 1), (267, 1), (268, 1), (269, 1), (270, 2), (271, 1)]
# request enquiry information flash  issue with ultimates submissionretraction
# [(3, 1), (17, 1), (43, 1), (45, 1), (48, 1), (272, 1), (273, 1), (274, 1)]
# request enquiry information flash  incorrect data in dubbing for  ts rfcst for mpm
# [(8, 1), (43, 1), (45, 1), (48, 1), (72, 2), (218, 1), (272, 1), (275, 1), (276, 1), (277, 1)]
# request enquiry information please run a vendor spend report for all software vendors pononpo to include tax code and tax amount from  present
# [(43, 1), (44, 1), (45, 1), (47, 1), (48, 1), (72, 1), (95, 1), (106, 1), (185, 1), (225, 1), (232, 1), (278, 1), (279, 1), (280, 1), (281, 1), (282, 1), (283, 1), (284, 1), (285, 2), (286, 1)]
# data mismatch records missing in table the following episodes of famous in love is not flowing to nts episode id
# [(8, 1), (28, 1), (32, 1), (177, 1), (265, 1), (270, 1), (287, 1), (288, 1), (289, 1), (290, 1), (291, 1), (292, 1), (293, 1), (294, 1)]
# data mismatch duplicate entry doubling in     hierarchy for
# [(8, 1), (72, 1), (80, 1), (292, 1), (295, 1), (296, 1), (297, 1)]
# access issue unable to access environment  rename the current sylvester tab in bw portal to participations allocation
# [(0, 2), (3, 1), (6, 1), (22, 1), (32, 1), (182, 1), (298, 1), (299, 1), (300, 1), (301, 1), (302, 1), (303, 1)]
# data request data update request complete estimate
# [(8, 2), (48, 2), (53, 1), (119, 1), (304, 1)]
# application batch job failure dvm analysis for technical tables in all systems
# [(1, 1), (49, 1), (72, 1), (97, 1), (99, 1), (184, 1), (278, 1), (305, 1), (306, 1), (307, 1), (308, 1)]
# access issue unable to access environment  add zsox to auditor role in all sox systems
# [(0, 2), (3, 1), (6, 1), (22, 1), (79, 1), (102, 1), (250, 1), (278, 1), (306, 1), (309, 1), (310, 1)]
# access issue unable to access application can you please process the following deal updoctest to  please let me know if you need further details
# [(0, 2), (1, 1), (3, 1), (6, 1), (9, 1), (32, 1), (34, 1), (106, 2), (208, 1), (290, 1), (311, 1), (312, 1), (313, 1), (314, 1), (315, 1), (316, 1), (317, 2)]
# general request general service request studionet possible smb bruteforce activity against studionet system
# [(48, 2), (54, 2), (55, 1), (230, 1), (318, 1), (319, 1), (320, 1), (321, 1), (322, 1), (323, 2)]
# application batch job monitoring   utility program crmdcustomeri sync issue monitoring
# [(1, 1), (3, 1), (49, 1), (99, 1), (324, 1), (325, 2), (326, 1), (327, 1), (328, 1)]
# data request test data helped hasit on testing part of incident
# [(8, 2), (48, 1), (73, 1), (329, 1), (330, 1), (331, 1), (332, 1), (333, 1)]
# data validation validation failed plant grid validation
# [(8, 1), (174, 3), (191, 1), (334, 1), (335, 1)]
# application code bug fix   close  sap  incorrect values
# [(1, 1), (95, 1), (142, 1), (276, 1), (336, 1), (337, 1), (338, 1), (339, 1)]
# access request unlock complete request  general service request
# [(0, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# access approval  accesssap issueunable to access environment complete request  general service request
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (48, 2), (53, 1), (54, 1), (55, 1)]
# data request test data test scenarios has been performed and helped hasit regarding
# [(8, 2), (48, 1), (185, 1), (329, 1), (330, 1), (332, 2), (340, 1), (341, 1), (342, 1), (343, 1), (344, 1)]
# request estimate enhancement complete estimate
# [(48, 1), (53, 1), (304, 2), (345, 1)]
# application code bug fix send only the exclusive territory holdbacks to cosmos
# [(1, 1), (32, 1), (95, 1), (209, 1), (336, 1), (338, 1), (346, 1), (347, 1), (348, 1), (349, 1), (350, 1)]
# application code bug fix remove avod svod and linear holdbacks and stage only the est and tvod
# [(1, 1), (32, 1), (60, 1), (95, 1), (185, 3), (336, 1), (338, 1), (347, 1), (348, 1), (351, 1), (352, 1), (353, 1), (354, 1), (355, 1), (356, 1)]
# application code bug fix one time conversion to restage the deals to sync holdbacks with cosmos
# [(1, 1), (17, 1), (32, 1), (95, 1), (156, 1), (209, 1), (327, 1), (336, 1), (338, 1), (347, 1), (357, 1), (358, 1), (359, 1), (360, 1)]
# configuration mapping error error found psl to sap transfer issue snu project
# [(3, 1), (23, 2), (59, 1), (137, 1), (142, 1), (153, 1), (205, 1), (248, 1), (361, 1), (362, 1)]
# service request service requests  batch job requested urgent consignment difference report zmmcondiff  set up scheduled job
# [(41, 1), (47, 1), (48, 1), (49, 1), (55, 2), (99, 2), (363, 1), (364, 1), (365, 1), (366, 1), (367, 1), (368, 1), (369, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant syawariya tapesh
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (370, 1), (371, 1)]
# application batch job monitoring cosmos batch job lists
# [(1, 1), (49, 2), (99, 2), (209, 1), (325, 1), (372, 1)]
# application issue ui refresh issue adding movie run
# [(1, 1), (3, 2), (89, 1), (225, 1), (373, 1), (374, 1)]
# access request unlock complete request  general service request
# [(0, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# access issue unable to access application tdm production cost details report issue
# [(0, 2), (1, 1), (3, 2), (6, 1), (47, 1), (77, 1), (312, 1), (375, 1), (376, 1)]
# access issue unable to access application please fix pds rsparam config per attached
# [(0, 2), (1, 1), (3, 1), (6, 1), (13, 1), (106, 1), (338, 1), (377, 1), (378, 1), (379, 1), (380, 1)]
# access issue unable to access application create web services in bds for sl hub alert configuration
# [(0, 2), (1, 1), (3, 1), (6, 1), (72, 1), (153, 1), (201, 1), (260, 1), (381, 1), (382, 1), (383, 1), (384, 1)]
# access issue unable to access transaction cosmos network sales rtpm
# [(0, 2), (3, 1), (6, 1), (209, 1), (220, 1), (231, 1), (385, 1), (386, 1)]
# general request general service request clearpass servers  configure systems to log centrally to
# [(48, 2), (54, 2), (55, 1), (85, 1), (120, 1), (306, 1), (387, 1), (388, 1), (389, 1)]
# data request data update request complete request  general service request
# [(8, 2), (48, 4), (53, 1), (54, 1), (55, 1), (119, 1)]
# data mismatch records missing in table ticket for the team
# [(8, 1), (32, 1), (70, 1), (72, 1), (177, 1), (292, 1), (293, 1), (294, 1), (390, 1)]
# request enquiry information complete estimate
# [(43, 1), (45, 1), (48, 1), (53, 1), (304, 1)]
# access sap issue unable to access environment  complete request  sap system open access process
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 1), (53, 1), (142, 2), (208, 1), (227, 1), (230, 1)]
# access request password reset monitoring services  great plains ar
# [(0, 1), (48, 1), (201, 1), (325, 1), (391, 1), (392, 1), (393, 1), (394, 1)]
# access request password reset request tabl auth for sctsadmi object be removed from all roles except basis charm and  be added to develop team role across all systems
# [(0, 1), (44, 1), (48, 2), (72, 1), (102, 1), (185, 1), (278, 2), (306, 1), (390, 1), (392, 1), (394, 1), (395, 1), (396, 1), (397, 1), (398, 1), (399, 1), (400, 1), (401, 1), (402, 1), (403, 1), (404, 1), (405, 1), (406, 1)]
# request enquiry information zp doctypes not being cleared properly
# [(28, 1), (43, 1), (45, 1), (48, 1), (407, 1), (408, 1), (409, 1), (410, 1)]
# request estimate enhancement  estimate two issues with vendor updates in psl
# [(17, 1), (48, 1), (108, 1), (205, 1), (232, 1), (304, 2), (345, 1), (411, 1), (412, 1)]
# data missing field missing in documents crm estimate effort to turn rim off for carrefour france
# [(8, 1), (72, 1), (212, 1), (293, 2), (304, 1), (413, 1), (414, 1), (415, 1), (416, 1), (417, 1), (418, 1), (419, 1), (420, 1)]
# request enquiry information  clear code sap
# [(43, 1), (45, 1), (48, 1), (95, 1), (134, 1), (142, 1)]
# application code bug fix unable to reject the item
# [(1, 1), (6, 1), (32, 1), (95, 1), (336, 1), (338, 1), (421, 1), (422, 1)]
# request enquiry information  reopen profit center
# [(43, 1), (45, 1), (48, 1), (423, 1), (424, 1), (425, 1)]
# application bdoc monitoring bdoc monitoring
# [(1, 1), (325, 2), (426, 2)]
# application reporting for week reporting for the week
# [(1, 1), (32, 1), (72, 2), (427, 2), (428, 2)]
# application reporting for week fa reporting for the week
# [(1, 1), (32, 1), (72, 2), (427, 2), (428, 2)]
# request enquiry information  change approver for mdh
# [(38, 1), (43, 1), (45, 1), (48, 1), (72, 1), (81, 1), (429, 1)]
# data request data update request exclude prs from vanmodautopocreate job
# [(8, 2), (44, 1), (48, 2), (99, 1), (119, 1), (430, 1), (431, 1), (432, 1)]
# access request account creation unlock printer achk in
# [(0, 1), (48, 1), (52, 1), (188, 1), (190, 1), (433, 1), (434, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant zalesinski radoslaw
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (435, 1), (436, 1)]
# request enquiry information stars new season calendars for
# [(43, 1), (45, 1), (48, 1), (68, 1), (72, 1), (437, 1), (438, 1), (439, 1)]
# access issue unable to access environment  iwbepsp access to basis admin role
# [(0, 3), (3, 1), (6, 1), (22, 1), (102, 1), (398, 1), (440, 1), (441, 1)]
# application monitoring healthcheck slhub  workday timer performance issue
# [(1, 1), (3, 1), (61, 1), (325, 1), (442, 1), (443, 1), (444, 1), (445, 1)]
# archival request backuprestore stars archival  season
# [(48, 1), (438, 1), (439, 1), (446, 2), (447, 1)]
# request enquiry information stars archival  season
# [(43, 1), (45, 1), (48, 1), (438, 1), (439, 1), (446, 1)]
# data data load issue data load failed brazil missing bookings for
# [(3, 1), (8, 3), (72, 1), (191, 1), (293, 1), (448, 1), (449, 1), (450, 2)]
# data data load issue data load failed brazil missing bookings lego batmankong skull island  king arthur the legend of the sword
# [(3, 1), (8, 3), (32, 2), (191, 1), (293, 1), (448, 1), (449, 1), (450, 2), (451, 1), (452, 1), (453, 1), (454, 1), (455, 1), (456, 1), (457, 1), (458, 1)]
# data data load issue data load failed stars bo load dayparts
# [(3, 1), (8, 3), (191, 1), (439, 1), (450, 3), (459, 1)]
# archival request backuprestore archive  stars database
# [(48, 1), (148, 1), (439, 1), (446, 1), (447, 1), (460, 1)]
# data request data update request urgent  complete request  general service request
# [(8, 2), (41, 1), (48, 4), (53, 1), (54, 1), (55, 1), (119, 1)]
# access issue unable to access application sap  access request
# [(0, 3), (1, 1), (3, 1), (6, 1), (48, 1), (142, 1)]
# data data load issue data load failed brazil missing bookings for
# [(3, 1), (8, 3), (72, 1), (191, 1), (293, 1), (448, 1), (449, 1), (450, 2)]
# request enquiry information urgent  complete request  change or configure an application
# [(1, 1), (41, 1), (43, 1), (45, 1), (48, 2), (53, 1), (81, 1), (85, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant alam md shahbaz
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (461, 1), (462, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant asif shaik
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (463, 1), (464, 1)]
# application code bug fix stars license fee change email notification list
# [(1, 1), (81, 1), (94, 1), (95, 1), (100, 1), (336, 1), (338, 1), (439, 1), (465, 1), (466, 1), (467, 1)]
# general request general service request please confirm the job list from your team to test them on pds server
# [(32, 1), (44, 1), (48, 2), (54, 2), (55, 1), (99, 1), (100, 1), (106, 1), (332, 1), (379, 1), (390, 1), (468, 1), (469, 1), (470, 1), (471, 1)]
# request estimate testing stars dev vip
# [(42, 1), (48, 1), (304, 1), (333, 1), (439, 1), (472, 1)]
# request enquiry information master data hub approver change
# [(8, 1), (38, 1), (43, 1), (45, 1), (48, 1), (81, 1), (109, 1), (383, 1)]
# data mismatch records missing in table data flow issue from sap to
# [(3, 1), (8, 2), (44, 1), (142, 1), (144, 1), (177, 1), (292, 1), (293, 1), (294, 1)]
# data request data update request issue downloading cosmos file report to be converted to excel
# [(3, 1), (8, 2), (47, 1), (48, 2), (119, 1), (209, 1), (473, 1), (474, 1), (475, 1), (476, 1)]
# access request password reset estimate  web service call zmcreatedigitalmaterial
# [(0, 1), (48, 1), (55, 1), (304, 1), (384, 1), (392, 1), (394, 1), (477, 1), (478, 1)]
# application configure request change or edit the application biannual audit clean upplease update the following request types in the mdh that have been identified now as
# [(1, 2), (31, 1), (32, 3), (48, 2), (81, 1), (85, 1), (98, 1), (119, 1), (135, 1), (249, 1), (290, 1), (340, 1), (429, 1), (479, 1), (480, 1), (481, 1), (482, 1), (483, 1), (484, 1)]
# report request report run query the mdh database to inlcude the all fields listed in the request types screen see screen shot attached
# [(32, 3), (47, 2), (48, 2), (148, 1), (225, 1), (278, 1), (377, 1), (429, 1), (483, 1), (485, 1), (486, 1), (487, 1), (488, 1), (489, 2), (490, 1), (491, 1)]
# request enquiry information sap finance team ticket
# [(43, 1), (45, 1), (48, 1), (70, 1), (142, 1), (390, 1), (492, 1)]
# access issue unable to access application cms theater details from maccs to tobi
# [(0, 2), (1, 1), (3, 1), (6, 1), (44, 1), (166, 1), (312, 1), (493, 1), (494, 1), (495, 1)]
# access request unlock complete estimate
# [(0, 1), (48, 1), (52, 1), (53, 1), (304, 1)]
# general request general service request  sapgui install request
# [(48, 3), (54, 2), (55, 1), (496, 1), (497, 1)]
# access request unlock complete estimate
# [(0, 1), (48, 1), (52, 1), (53, 1), (304, 1)]
# request enquiry information  how to research the franchise
# [(32, 1), (43, 1), (45, 1), (48, 1), (138, 1), (498, 1), (499, 1)]
# data mismatch incorrect data found amazon de    de  amazon eu sarl  sap   aic audit
# [(8, 2), (137, 1), (142, 1), (249, 1), (276, 1), (292, 1), (500, 1), (501, 2), (502, 1)]
# data mismatch incorrect data found asda uk      sap   aic audit
# [(8, 2), (137, 1), (142, 1), (249, 1), (276, 1), (292, 1), (500, 1), (503, 1)]
# report request report run master data hub  new tax code
# [(8, 1), (47, 2), (48, 1), (68, 1), (95, 1), (109, 1), (225, 1), (285, 1), (383, 1)]
# report request report run brazil missing bookings for
# [(47, 2), (48, 1), (72, 1), (225, 1), (293, 1), (448, 1), (449, 1)]
# report request report run grant read only access to navision corporate  archive  leavesden also install the app on her laptop
# [(0, 1), (32, 1), (47, 2), (48, 1), (225, 1), (348, 1), (460, 1), (496, 1), (504, 1), (505, 1), (506, 1), (507, 1), (508, 1), (509, 1), (510, 1), (511, 1), (512, 1)]
# application configure request change or edit the application mdh hub home page scrolling message update needed with upcoming freeze dates
# [(1, 2), (17, 1), (32, 1), (48, 1), (81, 1), (85, 1), (119, 1), (135, 1), (162, 1), (383, 1), (429, 1), (513, 1), (514, 1), (515, 1), (516, 1), (517, 1), (518, 1), (519, 1)]
# application configure request change or edit the application mdh improvement request as created by andrew b prior to his departureplease review and provide a status update by
# [(1, 2), (16, 1), (32, 1), (48, 2), (81, 1), (85, 1), (119, 1), (135, 1), (185, 1), (429, 1), (520, 1), (521, 1), (522, 1), (523, 1), (524, 1), (525, 1), (526, 1), (527, 1)]
# request enquiry information mdh new user welcome email and communication including revised user intake requirements please see email attachment and instructions provided earlier this week
# [(7, 2), (43, 1), (45, 1), (48, 1), (68, 1), (94, 2), (106, 1), (185, 2), (428, 1), (429, 1), (490, 1), (528, 1), (529, 1), (530, 1), (531, 1), (532, 1), (533, 1), (534, 1), (535, 1), (536, 1), (537, 1), (538, 1)]
# access request unlock owning company code repost  manual activity for  and  scenario
# [(0, 1), (48, 1), (52, 1), (72, 1), (95, 1), (96, 1), (185, 1), (224, 1), (318, 1), (539, 1), (540, 1), (541, 1)]
# request enquiry information access to master data hub
# [(0, 1), (8, 1), (43, 1), (45, 1), (48, 1), (109, 1), (383, 1)]
# data data flow data flow failure customer status in sap
# [(8, 3), (16, 1), (97, 1), (142, 1), (144, 2), (542, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant sternberg ashley
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (543, 1), (544, 1)]
# access issue unable to access application urgent  complete request  general service request
# [(0, 2), (1, 1), (3, 1), (6, 1), (41, 1), (48, 2), (53, 1), (54, 1), (55, 1)]
# application code bug fix amazon schedule line item issue breakfix
# [(1, 1), (3, 1), (71, 1), (95, 1), (210, 1), (336, 1), (338, 1), (421, 1), (501, 1), (545, 1)]
# application ip data data cleansing changes for the list of    ips for updating the itdi release windows and wbheg profile
# [(1, 1), (8, 2), (32, 2), (65, 1), (72, 2), (78, 1), (100, 1), (185, 1), (546, 1), (547, 1), (548, 1), (549, 1), (550, 1), (551, 1), (552, 1)]
# access issue unable to access environment  complete request  general service request
# [(0, 2), (3, 1), (6, 1), (22, 1), (48, 2), (53, 1), (54, 1), (55, 1)]
# application  testing dtd invoice printing fat in
# [(1, 1), (262, 1), (333, 1), (553, 1), (554, 1), (555, 1)]
# access issue unable to access application cmsbrazil missing bookings for the titles
# [(0, 2), (1, 1), (3, 1), (6, 1), (32, 1), (72, 1), (271, 1), (293, 1), (448, 1), (556, 1)]
# request enquiry information us theatrical release date for  titles not being interfaced to ipm
# [(28, 1), (43, 1), (45, 1), (48, 1), (72, 1), (78, 1), (271, 1), (407, 1), (557, 1), (558, 1), (559, 1), (560, 1)]
# request enquiry information edi invoices question re carrefour spain
# [(43, 1), (45, 1), (48, 1), (413, 1), (561, 1), (562, 1), (563, 1), (564, 1)]
# request estimate enhancement single sign on for stars
# [(48, 1), (72, 1), (304, 1), (345, 1), (439, 1), (565, 1), (566, 1)]
# data transmission issue trasmission not appearing in target system rtprosluk prd transmissions pdfs not found after
# [(3, 1), (8, 1), (28, 2), (137, 1), (147, 1), (159, 1), (230, 1), (239, 1), (242, 1), (243, 1), (567, 1), (568, 1), (569, 1), (570, 1)]
# access request access modification sap access request form – attention required – request form for applicant thimmaiah shilpa
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (571, 1), (572, 1)]
# access request access modification sap access request form – attention required – request form for applicant leu michelle
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (573, 1), (574, 1)]
# access issue unable to access application plm  determine location of component type to gl account mapping for plan vs actuals reports
# [(0, 2), (1, 1), (3, 1), (6, 1), (72, 1), (188, 1), (361, 1), (575, 1), (576, 1), (577, 1), (578, 1), (579, 1), (580, 1), (581, 1), (582, 1)]
# data mismatch incorrect data found sap  positive pay file not valid
# [(8, 2), (28, 1), (137, 1), (142, 1), (276, 1), (292, 1), (476, 1), (583, 1), (584, 1), (585, 1)]
# access sap issue unable to access environment  complete request  general service request
# [(0, 2), (3, 1), (6, 1), (22, 1), (48, 2), (53, 1), (54, 1), (55, 1), (142, 1)]
# application deal inclusion list qa approval
# [(1, 1), (9, 1), (20, 1), (100, 1), (586, 1)]
# data transaction issue transaction not posted in destination system check the configuration in sap for the newly created tv production comp codes
# [(3, 1), (8, 1), (28, 1), (32, 2), (72, 1), (77, 1), (142, 1), (153, 1), (226, 1), (228, 1), (230, 1), (231, 2), (269, 1), (521, 1), (587, 1), (588, 1), (589, 1)]
# request enquiry information complete request  general service request
# [(43, 1), (45, 1), (48, 3), (53, 1), (54, 1), (55, 1)]
# access request new access    request for reverse gr of po
# [(0, 2), (48, 2), (68, 1), (72, 1), (590, 1)]
# application deal cancellation issue request you to cancel the below listed scope in  system
# [(1, 1), (3, 1), (9, 1), (32, 1), (48, 1), (230, 1), (317, 1), (487, 1), (591, 1), (592, 1), (593, 1), (594, 1)]
# data transaction issue transaction not posted in destination system checks are failing to post in sap from lob systems
# [(3, 1), (8, 1), (28, 1), (44, 1), (142, 1), (192, 1), (226, 1), (228, 1), (230, 1), (231, 2), (306, 1), (595, 1), (596, 1), (597, 1), (598, 1)]
# request enquiry information difference in records
# [(43, 1), (45, 1), (48, 1), (294, 1), (364, 1)]
# access issue unable to access application complete estimate
# [(0, 2), (1, 1), (3, 1), (6, 1), (53, 1), (304, 1)]
# request enquiry information urgent  complete estimate
# [(41, 1), (43, 1), (45, 1), (48, 1), (53, 1), (304, 1)]
# general request general service request can you please check and let us know the below listed ar account status in gp
# [(16, 1), (32, 1), (48, 2), (54, 2), (55, 1), (106, 1), (185, 1), (188, 1), (311, 1), (314, 1), (315, 1), (317, 1), (487, 1), (587, 1), (591, 1)]
# report request report run  estimate request for ers  change to  limit threshold of electronic invoices
# [(47, 2), (48, 2), (72, 1), (81, 1), (225, 1), (304, 1), (562, 1), (599, 1), (600, 1), (601, 1), (602, 1)]
# request enquiry analysis  reload actual excluding year  in
# [(43, 1), (48, 1), (184, 1), (603, 1), (604, 1), (605, 1), (606, 1)]
# access request new access  sap access request form – attention required – request form for applicant housley torree
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (607, 1), (608, 1)]
# data transmission issue trasmission not appearing in target system rimca  on hands in rim are not being adjusted for bby ca
# [(3, 1), (8, 1), (28, 2), (72, 1), (159, 1), (192, 1), (230, 1), (239, 1), (242, 1), (243, 1), (407, 1), (419, 1), (609, 1), (610, 1), (611, 1), (612, 1)]
# access issue unable to access environment  provide access to schema wbdsupply in bhd for user xgpurams
# [(0, 3), (3, 1), (6, 1), (7, 1), (22, 1), (72, 1), (526, 1), (613, 1), (614, 1), (615, 1), (616, 1)]
# access request unlock sap
# [(0, 1), (48, 1), (52, 1), (142, 1)]
# request enquiry information  status but should not be
# [(16, 1), (28, 1), (43, 1), (45, 1), (48, 1), (617, 1), (618, 1)]
# access request access modification authorization issue while activating the service in bds system
# [(0, 2), (3, 1), (32, 1), (48, 1), (55, 1), (214, 1), (230, 1), (382, 1), (619, 1), (620, 1), (621, 1)]
# application issue not accessable users not able to work on  and emails not received
# [(1, 1), (3, 1), (28, 3), (185, 1), (622, 1), (623, 1), (624, 1), (625, 1), (626, 1), (627, 1)]
# access request access modification   sap access request form – attention required – request form for applicant eshima natsuko
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (628, 1), (629, 1)]
# sap dumps issue runtime error dumps urgent  complete request  general service request
# [(3, 1), (23, 1), (41, 1), (48, 2), (53, 1), (54, 1), (55, 1), (142, 1), (630, 2), (631, 1)]
# data data load issue data load failed batch balancing issue
# [(3, 2), (8, 3), (49, 1), (191, 1), (450, 2), (632, 1)]
# access request account creation   sap access request form – attention required – request form for applicant mustafa shadab
# [(0, 2), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (188, 1), (190, 1), (633, 1), (634, 1)]
# access request new access sap access request form – attention required – request form for applicant mustafa shadab
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (633, 1), (634, 1)]
# access request access modification sap access request form – attention required – request form for applicant kumar periwal anuj
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (635, 1), (636, 1), (637, 1)]
# request enquiry information  request to update bank details
# [(43, 1), (45, 1), (48, 2), (119, 1), (312, 1), (638, 1)]
# request estimate enhancement complete estimate
# [(48, 1), (53, 1), (304, 2), (345, 1)]
# access request new access sap access request form – attention required – request form for applicant chu alvin
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (639, 1), (640, 1)]
# request estimate testing testing effort for window  upgrade
# [(48, 1), (72, 1), (169, 1), (304, 1), (333, 2), (415, 1), (641, 1)]
# general request general service request please investigate these stuck transmissions and help us to understand reason for failure
# [(48, 2), (54, 2), (55, 1), (64, 1), (72, 1), (97, 1), (106, 1), (143, 1), (147, 1), (185, 1), (240, 1), (642, 1), (643, 1), (644, 1)]
# data transmission issue idoc failure   outbound  idocs  status  debmas
# [(3, 1), (8, 1), (16, 1), (97, 1), (159, 1), (261, 1), (645, 1), (646, 1), (647, 1)]
# data issue incorrect data in backend sap security please provide role for zmpmmaint
# [(3, 1), (8, 2), (72, 1), (102, 1), (106, 1), (142, 1), (276, 1), (526, 1), (648, 1), (649, 1), (650, 1)]
# request enquiry information  access on sap
# [(0, 1), (43, 1), (45, 1), (48, 1), (142, 1)]
# application deal inclusion list qa approval
# [(1, 1), (9, 1), (20, 1), (100, 1), (586, 1)]
# general request general service request provide lob details for transmission
# [(48, 2), (54, 2), (55, 1), (72, 1), (159, 1), (312, 1), (526, 1), (597, 1)]
# access issue unable to access application  trace giving dump
# [(0, 2), (1, 1), (3, 1), (6, 1), (651, 1), (652, 1), (653, 1)]
# data validation validation failed rim  pack product discrepancy
# [(8, 1), (174, 2), (191, 1), (419, 1), (654, 1), (655, 1), (656, 1)]
# request enquiry information   sap  bank number field is longer than  characters
# [(43, 1), (45, 1), (48, 1), (142, 1), (263, 1), (416, 1), (638, 1), (657, 1), (658, 1), (659, 1)]
# data mismatch records missing in table  there is some data flow issue from sap to  for the following titles
# [(3, 1), (8, 2), (32, 1), (44, 1), (72, 1), (142, 1), (144, 1), (177, 1), (271, 1), (290, 1), (292, 1), (293, 1), (294, 1), (660, 1), (661, 1)]
# access request access modification  sap access issue
# [(0, 3), (3, 1), (48, 1), (142, 1), (214, 1)]
# report request report run rim team to run a walmart oh report for   going in style dvd include total mins
# [(47, 3), (48, 1), (72, 1), (225, 2), (280, 1), (390, 1), (419, 1), (662, 1), (663, 1), (664, 1), (665, 1), (666, 1), (667, 1)]
# data mismatch duplicate entry master data team to update the cons unit  in     doubled up
# [(8, 2), (32, 1), (109, 1), (119, 1), (292, 1), (296, 1), (297, 1), (390, 1), (668, 1), (669, 1), (670, 1)]
# access request unlock complete request  general service request
# [(0, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# serverservicewebsite connection issue services are down sps commerce edi  system maintenance   cst
# [(3, 1), (192, 1), (194, 1), (195, 1), (200, 1), (201, 1), (230, 1), (561, 1), (671, 1), (672, 1), (673, 1), (674, 1)]
# data data load issue data load failed  tx shuttle script to reject po line items is not working
# [(3, 1), (8, 3), (28, 1), (150, 1), (191, 1), (210, 1), (422, 1), (450, 2), (675, 1), (676, 1), (677, 1)]
# request enquiry information modify balance in group mpm
# [(25, 1), (43, 1), (45, 1), (48, 1), (113, 1), (218, 1), (678, 1)]
# authorization issue user understanding issue  purchase order
# [(3, 2), (7, 1), (82, 1), (620, 1), (679, 1), (680, 1)]
# access request remove access  starters leavers
# [(0, 2), (48, 1), (60, 1), (681, 1), (682, 1)]
# access issue unable to access environment  remove profit center and company code combination check in  and
# [(0, 2), (3, 1), (6, 1), (22, 1), (60, 1), (95, 1), (96, 1), (185, 2), (423, 1), (424, 1), (587, 1), (683, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant mehrzai faisal
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (684, 1), (685, 1)]
# access request access modification sap access request form – attention required – request form for applicant canasi brittany
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (686, 1), (687, 1)]
# request estimate testing testing production accouting interfaces following security upgrade
# [(48, 1), (77, 1), (169, 1), (290, 1), (304, 1), (333, 2), (649, 1), (688, 1), (689, 1)]
# access approval  accesssap issueunable to access environment plm process chain monitoring for week  to
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (72, 1), (208, 1), (325, 1), (428, 1), (580, 1), (690, 1)]
# access approval  accesssap issueunable to access environment plm portal health check for week  to
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (72, 1), (182, 1), (428, 1), (580, 1), (587, 1), (691, 1)]
# data mismatch data reconciliation daily idocs reconciliation carried out on
# [(8, 2), (36, 2), (92, 1), (292, 1), (646, 1), (692, 1), (693, 1)]
# access request access modification error in sap access form
# [(0, 3), (23, 1), (48, 1), (129, 1), (142, 1), (214, 1)]
# access approval  accesssap issueunable to access environment cosmos itd and dtd bwp monitoring for the week starting from  to
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (32, 1), (44, 1), (72, 1), (185, 1), (209, 1), (325, 1), (428, 1), (553, 1), (694, 1), (695, 1), (696, 1)]
# access request provide access add user urgent  complete request  general service request
# [(0, 2), (7, 1), (41, 1), (48, 3), (53, 1), (54, 1), (55, 1), (79, 1), (526, 1)]
# report request report run move the submissions to shooting stars office
# [(32, 1), (47, 2), (48, 1), (225, 1), (439, 1), (697, 1), (698, 1), (699, 1), (700, 1)]
# request enquiry information  issue with sap
# [(3, 1), (17, 1), (43, 1), (45, 1), (48, 1), (142, 1)]
# request enquiry information urgent  complete request  general service request
# [(41, 1), (43, 1), (45, 1), (48, 3), (53, 1), (54, 1), (55, 1)]
# serverservicewebsite connection issue services are down  bw load status needed
# [(3, 1), (16, 1), (192, 1), (194, 1), (195, 1), (200, 1), (201, 1), (450, 1), (517, 1)]
# request enquiry information mdh
# [(43, 1), (45, 1), (48, 1), (429, 1)]
# request enquiry information mdh
# [(43, 1), (45, 1), (48, 1), (429, 1)]
# access issue unable to access application admnessbase monitoring weekly backup plmand optimization
# [(0, 2), (1, 1), (3, 1), (6, 1), (325, 1), (701, 1), (702, 1), (703, 1), (704, 1), (705, 1)]
# jobprocess schedule  run jobs  backups admn  incident report extraction
# [(47, 1), (51, 1), (73, 1), (225, 1), (545, 1), (706, 1), (707, 1), (708, 1), (709, 1)]
# request estimate enhancement slhub dependency removal
# [(48, 1), (304, 1), (345, 1), (444, 1), (710, 1), (711, 1)]
# application monitoring healthcheck cosmos fccdtd jobs monitoring
# [(1, 1), (51, 1), (209, 1), (325, 2), (442, 1), (712, 1)]
# request enquiry information complete request  general service request
# [(43, 1), (45, 1), (48, 3), (53, 1), (54, 1), (55, 1)]
# access issue unable to access environment  inquiry about roles
# [(0, 2), (3, 1), (6, 1), (22, 1), (404, 1), (713, 1), (714, 1)]
# access request access modification   sap access request form – attention required – request form for applicant haque shafia
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (715, 1), (716, 1)]
# data mismatch incorrect data found technicolor north america   sla breach
# [(8, 2), (137, 1), (276, 1), (292, 1), (717, 1), (718, 1), (719, 1), (720, 1), (721, 1)]
# request enquiry information cadency balance issue reocurring
# [(3, 1), (43, 1), (45, 1), (48, 1), (678, 1), (722, 1), (723, 1)]
# access request new access sap access request form – attention required – request form for applicant cho johnna
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (724, 1), (725, 1)]
# access request new access sap access request form – attention required – request form for applicant eckerle glenn
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (726, 1), (727, 1)]
# access request new access sap access request form – attention required – request form for applicant reyter elena
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (728, 1), (729, 1)]
# access request new access sap access request form – attention required – request form for applicant rodriguez natalie
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (730, 1), (731, 1)]
# access request access modification request for cbs application portal role details to access documents from wb portal
# [(0, 3), (1, 1), (44, 1), (48, 2), (63, 1), (72, 1), (102, 1), (182, 2), (214, 1), (312, 1), (414, 1)]
# access request access modification sap access request form – attention required – request form for applicant huynh david
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (732, 1), (733, 1)]
# access request new access sap access request form – attention required – request form for applicant darden briar
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (734, 1), (735, 1)]
# data request data update request create  new sap zvvr sub brand
# [(8, 2), (48, 2), (68, 1), (119, 1), (142, 1), (260, 1), (736, 1), (737, 1), (738, 1)]
# access request new access sap access request form – attention required – request form for applicant rideout joi
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (739, 1), (740, 1)]
# access request access modification sap access request form – attention required – request form for applicant riley christopher
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (741, 1), (742, 1)]
# access request access modification sap access request form – attention required – request form for applicant rey richard
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (743, 1), (744, 1)]
# access request access modification sap access request form – attention required – request form for applicant dalglish charles
# [(0, 3), (48, 3), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (214, 1), (745, 1), (746, 1)]
# request estimate enhancement bwupdate email config to point cycle for bcs
# [(48, 1), (72, 1), (94, 1), (304, 1), (345, 1), (378, 1), (747, 1), (748, 1), (749, 1), (750, 1)]
# application monitoring healthcheck event builder map upload
# [(1, 1), (325, 1), (442, 1), (751, 1), (752, 1), (753, 1), (754, 1)]
# access issue unable to access environment  sap access request form – attention required – request form for applicant brown krystle
# [(0, 3), (3, 1), (6, 1), (22, 1), (48, 2), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (755, 1), (756, 1)]
# access issue unable to access application create hana studio users in hana db soq and sod
# [(0, 2), (1, 1), (3, 1), (6, 1), (185, 1), (260, 1), (626, 1), (757, 2), (758, 1), (759, 1), (760, 1)]
# data data flow data flow failure pslsap issues  constantine  pilot
# [(8, 3), (97, 1), (108, 1), (144, 2), (761, 1), (762, 1), (763, 1)]
# data data flow data flow failure recon tool issue  shameless  series
# [(3, 1), (8, 3), (97, 1), (144, 2), (207, 1), (244, 1), (245, 1), (764, 1)]
# request enquiry information sap production cost data missing from  interface
# [(8, 1), (43, 1), (44, 1), (45, 1), (48, 1), (77, 1), (142, 1), (293, 1), (375, 1), (765, 1)]
# order po issue po not generated correctly    failure
# [(3, 1), (28, 1), (82, 1), (97, 1), (255, 1), (766, 1)]
# data data flow data flow failure pslsap issue  mom  series
# [(3, 1), (8, 3), (97, 1), (144, 2), (207, 1), (763, 1), (767, 1)]
# data data flow data flow failure pslsap issue  shameless  series
# [(3, 1), (8, 3), (97, 1), (144, 2), (207, 1), (763, 1), (764, 1)]
# data data flow data flow failure pslsap issue  gilmore girls  series
# [(3, 1), (8, 3), (97, 1), (144, 2), (207, 1), (763, 1), (768, 1), (769, 1)]
# access request account creation provide access for sap solution manager
# [(0, 2), (48, 1), (72, 1), (142, 1), (188, 1), (190, 1), (526, 1), (770, 1), (771, 1)]
# access request unlock complete request  general service request
# [(0, 1), (48, 3), (52, 1), (53, 1), (54, 1), (55, 1)]
# data mismatch records missing in table push the idocs for under suspicion with mpm
# [(8, 1), (17, 1), (32, 1), (72, 1), (177, 1), (218, 1), (292, 1), (293, 1), (294, 1), (646, 1), (772, 1), (773, 1), (774, 1)]
# access request password reset statement report    gp
# [(0, 1), (47, 1), (48, 1), (392, 1), (394, 1), (775, 1)]
# request enquiry information create a test id
# [(43, 1), (45, 1), (48, 1), (260, 1), (332, 1)]
# access issue unable to access application we are getting time out error in bo for large selections in production can you please send the output file and no of records for below selections we do not ha
# ...
# access issue unable to access environment  urgent  complete request  reset sap support staff password
# [(0, 2), (3, 1), (6, 1), (22, 1), (41, 1), (48, 1), (53, 1), (117, 1), (142, 1), (392, 1), (394, 1), (987, 1)]
# general request general service request urgent  complete request  rerun jobs run backups etc
# [(41, 1), (48, 3), (51, 1), (53, 1), (54, 2), (55, 1), (225, 1), (707, 1), (1814, 1), (1815, 1)]
# order po issue po not generated correctly  po copy for the po
# [(3, 1), (28, 1), (32, 1), (72, 1), (82, 1), (255, 1), (766, 1), (1083, 1)]
# access approval  accesssap issueunable to access environment pod is not working
# [(0, 2), (18, 1), (20, 1), (22, 1), (26, 1), (28, 1), (677, 1), (1296, 1)]
# application ip data data cleansing  prd error log file
# [(1, 1), (8, 2), (23, 1), (120, 1), (476, 1), (547, 1), (569, 1)]
# access request new access complete request  general service request
# [(0, 2), (48, 3), (53, 1), (54, 1), (55, 1), (68, 1)]
# configuration mapping error error found cm number  not posted on account
# [(23, 2), (28, 1), (137, 1), (153, 1), (188, 1), (228, 1), (263, 1), (361, 1)]
# application monitoring healthcheck rimusa monitoring replen runsorders wc from  to
# [(1, 1), (44, 1), (325, 2), (442, 1), (1104, 1), (1105, 1), (1106, 1)]
# application monitoring healthcheck health rimusa monitoring jobsdata loadsalertsqueue wc from  to
# [(1, 1), (44, 1), (325, 2), (442, 1), (691, 1), (1105, 1), (1113, 1), (1114, 1)]
# application monitoring healthcheck rimemea monitor jobsqueuesalertsorders for all emea territories wc from  to
# [(1, 1), (44, 1), (72, 1), (278, 1), (325, 1), (442, 1), (862, 1), (1115, 1), (1116, 1), (1117, 1), (1118, 1)]
# jobprocess schedule  run jobs  backups rimbn  count file load for mediamarkt nlbe
# [(51, 1), (72, 1), (225, 1), (450, 1), (476, 1), (545, 1), (707, 1), (709, 1), (1109, 1), (1112, 1), (1425, 1), (3783, 1)]
# access issue unable to access application urgent  complete request  general service request
# [(0, 2), (1, 1), (3, 1), (6, 1), (41, 1), (48, 2), (53, 1), (54, 1), (55, 1)]
# access request new access complete request  general service request
# [(0, 2), (48, 3), (53, 1), (54, 1), (55, 1), (68, 1)]
# request enquiry analysis   sap prd issue
# [(3, 1), (43, 1), (48, 1), (142, 1), (184, 1), (569, 1)]
# authorization error access issue for evaluation urgent  complete request  general service request
# [(0, 1), (3, 1), (23, 1), (41, 1), (48, 2), (53, 1), (54, 1), (55, 1), (72, 1), (620, 1), (3034, 1)]
# data issue missing program id rpp issue   while loading program cross reference file
# [(3, 2), (8, 1), (293, 1), (326, 2), (476, 1), (621, 1), (902, 1), (925, 1), (3667, 1), (3784, 1)]
# access request new access need access to bws system
# [(0, 3), (34, 1), (48, 1), (68, 1), (230, 1), (3785, 1)]
# data transmission issue incorrect status inbound  error from amazon jp
# [(3, 1), (8, 1), (16, 1), (23, 1), (44, 1), (159, 1), (276, 1), (501, 1), (1169, 1)]
# data issue incorrect data in backend remove entry from distribution model for zmatmas and debmas for cinramde
# [(3, 1), (8, 2), (44, 1), (60, 1), (72, 2), (185, 1), (276, 1), (297, 1), (645, 1), (648, 1), (780, 1), (1205, 1), (1958, 1), (3786, 1)]
# access request new access  sap extend account
# [(0, 2), (48, 1), (68, 1), (142, 1), (188, 1), (216, 1)]
# application code bug fix add the isactive column to eps scheduling schema
# [(1, 1), (32, 1), (79, 1), (95, 1), (221, 1), (336, 1), (338, 1), (614, 1), (846, 1), (3739, 1), (3740, 1)]
# access request new access please review sap security note  for implementation in scp
# [(0, 2), (48, 1), (68, 1), (72, 1), (106, 1), (142, 1), (527, 1), (649, 1), (787, 1), (1313, 1), (1314, 1)]
# request estimate enhancement add the eps scheduling tables to the archival process
# [(32, 2), (48, 1), (79, 1), (208, 1), (221, 1), (304, 1), (307, 1), (345, 1), (446, 1), (3739, 1)]
# application monitoring healthcheck rimge  weekly stock file monitoring for mediasaturn
# [(1, 1), (72, 1), (325, 2), (442, 1), (476, 1), (705, 1), (1069, 1), (1316, 1), (1317, 1)]
# data data flow data flow failure   errors in scp clearing cif stuck queues  on
# [(8, 3), (97, 1), (136, 1), (144, 2), (643, 1), (787, 1), (982, 1), (983, 1), (984, 1)]
# data mismatch records missing in table cadency balance issue
# [(3, 1), (8, 1), (177, 1), (292, 1), (293, 1), (294, 1), (678, 1), (722, 1)]
# data mismatch incorrect data found complete request  general service request
# [(8, 2), (48, 2), (53, 1), (54, 1), (55, 1), (137, 1), (276, 1), (292, 1)]
# access issue unable to access application tobi italy booking chart issue
# [(0, 2), (1, 1), (3, 2), (6, 1), (495, 1), (792, 1), (3173, 1), (3787, 1)]
# data request data update request sony charge code upload
# [(8, 2), (48, 2), (95, 1), (119, 1), (754, 1), (1079, 1), (1080, 1)]
# report request report run slhub  remediation of security vulnerabilities
# [(47, 2), (48, 1), (151, 1), (225, 1), (444, 1), (649, 1), (882, 1)]
# general request general service request delete line item or review button not working
# [(10, 1), (28, 1), (48, 2), (54, 2), (55, 1), (210, 1), (421, 1), (527, 1), (677, 1), (2823, 1)]
# access request access modification not able to activate the pdf form in sfp transaction  getting error like soap framework errorsoap runtime exception csoapexception transporthttp send return
# [(0, 2), (23, 1), (28, 1), (32, 1), (48, 1), (129, 1), (167, 1), (204, 1), (214, 1), (231, 1), (349, 1), (622, 1), (631, 1), (776, 1), (1758, 1), (3556, 1), (3788, 1), (3789, 1), (3790, 1), (3791, 1), (3792, 1), (3793, 1), (3794, 1)]
# application batch job monitoring cosmos batch job monitoring for the week
# [(1, 1), (32, 1), (49, 2), (72, 1), (99, 2), (209, 1), (325, 2), (428, 1)]
# application bdoc monitoring cosmos bdoc monitoring for the week
# [(1, 1), (32, 1), (72, 1), (209, 1), (325, 2), (426, 2), (428, 1)]
# access request new access complete request  general service request
# [(0, 2), (48, 3), (53, 1), (54, 1), (55, 1), (68, 1)]
# access issue unable to access environment   sap password reset see related
# [(0, 2), (3, 1), (6, 1), (22, 1), (142, 1), (176, 1), (392, 1), (394, 1), (490, 1)]
# application reporting for week cosmos reporting  for the week
# [(1, 1), (32, 1), (72, 2), (209, 1), (427, 2), (428, 2)]
# request enquiry information please run the weekly full refresh on stars  environment for dma rank load to get generated on stars bo reports
# [(22, 1), (32, 1), (43, 1), (45, 1), (48, 1), (72, 1), (89, 1), (106, 1), (154, 1), (225, 1), (439, 2), (450, 1), (581, 1), (705, 1), (766, 1), (1325, 1), (3795, 1), (3796, 1)]
# access issue unable to access environment   in request to reset password for the following ids in devqa and prod
# [(0, 2), (3, 1), (6, 1), (22, 1), (32, 1), (48, 1), (72, 1), (185, 1), (290, 1), (392, 1), (394, 1), (1020, 1), (1419, 1), (3797, 1)]
# request enquiry information  production company code information related to ip
# [(43, 1), (45, 2), (48, 1), (77, 1), (95, 1), (96, 1), (176, 1)]
# report request report run the below ids under the  are in status
# [(16, 1), (32, 2), (47, 2), (48, 1), (192, 1), (225, 1), (591, 1), (774, 1), (1020, 1)]
# authorization issue maintain table entry update zoemailid
# [(3, 1), (119, 1), (177, 1), (197, 1), (297, 1), (620, 1), (1558, 1)]
# access issue unable to access environment  cosmos itd and dtd reconciliation for
# [(0, 2), (3, 1), (6, 1), (22, 1), (36, 1), (72, 1), (185, 1), (209, 1), (553, 1), (695, 1)]
# delete data deletion as per user requirement please run the program bpcmigratetohana
# [(7, 1), (8, 1), (10, 1), (11, 1), (13, 1), (15, 1), (32, 1), (106, 1), (225, 1), (326, 1), (1153, 1)]
# data mismatch records missing in table interface issue from maccs to sap
# [(3, 1), (8, 1), (44, 1), (142, 1), (166, 1), (177, 1), (292, 1), (293, 1), (294, 1), (765, 1)]
# request enquiry analysis  hi abap team  param  as discussed i have create the  for further analyzing the issue for interfaced end  request you to please let us the issue
# [(3, 2), (32, 3), (43, 1), (48, 2), (72, 2), (98, 1), (106, 1), (184, 1), (260, 1), (313, 1), (315, 1), (317, 1), (390, 1), (558, 1), (1191, 1), (1244, 1), (1310, 1), (3268, 1), (3798, 1)]
# access request new access wbconnect access
# [(0, 3), (48, 1), (66, 1), (68, 1)]
# access request access modification wbconnect access
# [(0, 3), (48, 1), (66, 1), (214, 1)]
# report mismatch correction of amount reconcile the difference of stations between  and  seasons
# [(32, 1), (47, 1), (185, 1), (279, 1), (292, 1), (364, 1), (873, 1), (1320, 1), (2825, 1), (3799, 1), (3800, 1)]
# access issue unable to access environment   sap xrp account unlock password reset request
# [(0, 2), (3, 1), (6, 1), (22, 1), (48, 1), (52, 1), (142, 1), (188, 1), (392, 1), (394, 1), (860, 1)]
# data mismatch incorrect data found there is a difference between sub ledger  currency exchange account for cc
# [(8, 2), (72, 1), (137, 1), (188, 1), (256, 1), (276, 1), (292, 1), (364, 1), (661, 1), (737, 1), (873, 1), (874, 1), (875, 1)]
# access request access modification  access to sap
# [(0, 3), (48, 1), (142, 1), (214, 1)]
# access request new access approver name not showing in srm reporting
# [(0, 2), (28, 1), (38, 1), (48, 1), (68, 1), (111, 1), (229, 1), (427, 1), (1882, 1)]
# access request new access sap access request form – attention required – request form for applicant sreekumaran suchithra
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (3801, 1), (3802, 1)]
# access request extension of validity of a user sap deactivation
# [(0, 1), (7, 1), (48, 1), (142, 1), (1016, 1), (1496, 1), (1565, 1)]
# application monitoring idocs daily idocs monitoring carried out on
# [(1, 1), (92, 1), (325, 2), (646, 2), (692, 1), (693, 1)]
# report reconciliation comparison of values between reports daily idocs reconciliation carried out on
# [(36, 2), (47, 1), (92, 1), (339, 1), (581, 1), (646, 1), (692, 1), (693, 1), (873, 1), (1318, 1)]
# access request new access sap access request form – attention required – request form for applicant gioda elena
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (728, 1), (3803, 1)]
# access request new access unable to login  gui user id xclakshm
# [(0, 2), (6, 1), (7, 1), (48, 1), (68, 1), (1410, 1), (1478, 1), (3804, 1)]
# request estimate enhancement estimate request effort to test elmer compatibility with windows
# [(17, 1), (48, 2), (304, 2), (332, 1), (345, 1), (415, 1), (552, 1), (2035, 1), (3805, 1)]
# access request new access sap access request form – attention required – request form for applicant falenciak pawel
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (2075, 1), (3806, 1)]
# access request new access sap access request form – attention required – request form for applicant zalesinski radoslaw
# [(0, 3), (48, 3), (68, 1), (72, 1), (126, 1), (127, 1), (129, 2), (132, 1), (142, 1), (435, 1), (436, 1)]
# access issue unable to access environment  bwp system monitoring from  to
# [(0, 2), (3, 1), (6, 1), (22, 1), (44, 1), (230, 1), (325, 1), (694, 1)]
# access issue unable to access environment  broadcast job monitoring  from  to
# [(0, 2), (3, 1), (6, 1), (22, 1), (44, 1), (99, 1), (325, 1), (1084, 1)]
# request enquiry information bpc monitoring activities
# [(43, 1), (45, 1), (48, 1), (325, 1), (966, 1), (1168, 1)]
# general request estimate estimate  target us  invoice map change  remove po logic
# [(48, 1), (54, 1), (60, 1), (81, 1), (242, 1), (262, 1), (304, 2), (753, 1), (1870, 1)]
# report daily activity daily report creation  inbound error report
# [(23, 1), (47, 3), (190, 1), (318, 1), (693, 2), (1169, 1)]
# report weekly activity report creation outbound error report
# [(23, 1), (47, 3), (190, 1), (318, 1), (647, 1), (705, 1)]
# access request provide access add user new vmeasy account for ben ransom
# [(0, 2), (7, 1), (48, 1), (68, 1), (72, 1), (79, 1), (188, 1), (526, 1), (3807, 1), (3808, 1), (3809, 1)]
# data shopping cart shopping cart error sap procurement srm and mm cart deletion
# [(8, 1), (11, 1), (23, 1), (107, 3), (110, 2), (111, 1), (142, 1), (185, 1), (3810, 1)]
# access issue unable to access application access to nonproduction sap
# [(0, 3), (1, 1), (3, 1), (6, 1), (142, 1), (1321, 1)]
# report request report run bpc adhoc recon activity
# [(47, 2), (48, 1), (225, 1), (244, 1), (318, 1), (966, 1), (1805, 1)]
# general request general service request  please provide the prd backup of picture perfect db to tyco
# [(32, 1), (48, 2), (54, 2), (55, 1), (106, 1), (526, 1), (569, 1), (702, 1), (1050, 1), (2728, 1), (3811, 1)]
# report request report run fcst adhoc recon activity
# [(47, 2), (48, 1), (225, 1), (244, 1), (318, 1), (901, 1), (1805, 1)]
# access issue unable to access transaction remove roles from sap prd account
# [(0, 2), (3, 1), (6, 1), (44, 1), (60, 1), (142, 1), (188, 1), (231, 1), (404, 1), (569, 1)]
# access request unlock add printer to sap
# [(0, 1), (48, 1), (52, 1), (79, 1), (142, 1), (434, 1)]
# access request new access  sap account moved to delete group
# [(0, 2), (10, 1), (25, 1), (48, 1), (68, 1), (142, 1), (188, 1), (831, 1)]
# application code bug fix this invoice for ingram customer is showing as  net revenue in business objects
# [(1, 1), (72, 1), (95, 1), (105, 1), (193, 1), (229, 1), (262, 1), (336, 1), (338, 1), (537, 1), (542, 1), (1100, 1), (1275, 1), (2780, 1)]
# access request new access complete request  general service request
# [(0, 2), (48, 3), (53, 1), (54, 1), (55, 1), (68, 1)]
# request enquiry information mdh sap approvers matrix update remove valerie valdez from all mdh approvers work flow approvals
# [(43, 1), (44, 1), (45, 1), (48, 1), (60, 1), (119, 1), (142, 1), (144, 1), (278, 1), (429, 2), (627, 1), (1520, 1), (1636, 2), (2200, 1), (2730, 1), (3812, 1)]
# access request new access password reset
# [(0, 2), (48, 1), (68, 1), (392, 1), (394, 1)]
# application issue not accessable please process the  denied cases for target to inymbus
# [(1, 1), (3, 1), (28, 1), (32, 1), (72, 1), (106, 1), (179, 1), (181, 1), (208, 1), (242, 1), (623, 1), (3813, 1)]
# request enquiry information ach lockbox for
# [(43, 1), (45, 1), (48, 1), (72, 1), (1333, 1), (3814, 1)]
# approval error unable to approve please assist with the cmr workflow for
# [(6, 1), (17, 1), (20, 1), (23, 1), (32, 1), (72, 1), (106, 1), (823, 1), (897, 1), (3318, 1), (3815, 1)]
# authorization issue unavailability of role access to transactions
# [(0, 1), (3, 1), (102, 1), (620, 1), (1014, 1), (3816, 1)]
# data missing field missing in documents   outbound  idocs  status   debmas
# [(8, 1), (16, 1), (293, 2), (414, 1), (416, 1), (645, 1), (646, 1), (647, 1)]
# request enquiry information please resend the below two files to ota failed due to eai db issue
# [(3, 1), (32, 1), (43, 1), (45, 1), (48, 1), (106, 1), (191, 1), (411, 1), (591, 1), (868, 1), (1110, 1), (1148, 1), (1824, 1), (2973, 1)]
# access request new access request history
# [(0, 2), (48, 2), (68, 1), (3430, 1)]
# access request remove access leavesden leavers
# [(0, 2), (48, 1), (60, 1), (510, 1), (681, 1)]
# access issue unable to access application saprequest for bo user account creation cvelazqu
# [(0, 2), (1, 1), (3, 1), (6, 1), (7, 1), (72, 1), (188, 1), (190, 1), (3817, 1), (3818, 1)]
# access issue unable to access application tobirequest for bo user account creation xkbarszc
# [(0, 2), (1, 1), (3, 1), (6, 1), (7, 1), (72, 1), (188, 1), (190, 1), (3819, 1), (3820, 1)]
# access request remove access leavesden leavers
# [(0, 2), (48, 1), (60, 1), (510, 1), (681, 1)]
# access request new access update xsbommar in wpp to assign  and remove old wpwzbasadm roles
# [(0, 2), (48, 1), (60, 1), (68, 1), (119, 1), (185, 1), (404, 1), (871, 1), (1305, 1), (1962, 1), (3821, 1), (3822, 1)]
# access issue unable to access environment   office  migration
# [(0, 2), (3, 1), (6, 1), (22, 1), (46, 1), (698, 1)]
# request enquiry information business is looking for steps and sap screen shot for below sap project extract
# [(43, 1), (45, 1), (48, 1), (59, 1), (72, 2), (142, 2), (185, 1), (193, 1), (489, 1), (491, 1), (591, 1), (1067, 1), (3653, 1), (3823, 1)]
# Wall time: 1.43 s

# %%
# %%time
#question_orig="do I need to learn algorithms to be a data scientist ?";
query= "Unable to access application"
query=clean_sentence(query,stopwords=True);
query_embedding = dictionary.doc2bow(query.split())


print("\n\n",query,"\n",query_embedding)
# Out:
#  unable access application
#  [(0, 1), (1, 1), (6, 1)]
# Wall time: 1 ms

# %%
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

def get_cosim(query,docs):
      
    count = []
    simscore = []
    result = []

    for index,faq_embedding in enumerate(docs):
            sim=cosine_similarity(faq_embedding,query)[0][0]

            count.append(index)
            simscore.append(sim)
            result.append(sentences[index])



    dfScore = pd.DataFrame(list(zip(count, simscore, result)),
                  columns=['id','simscore', 'result'])


    dfsort = dfScore.sort_values('simscore', ascending = False)


    return dfsort

# %%
# Getting Phrase Embeddings from Word Embeddings

def getWordVec(word,model):
        samp=model['users']
        vec=[0]*len(samp);
        try:
                vec=model[word]
        except:
                vec=[0]*len(samp)
        return (vec)


def getPhraseEmbedding(phrase,embeddingmodel):
                       
        samp=getWordVec('users', embeddingmodel)
        vec=np.array([0]*len(samp));
        den=0;
        for word in phrase.split():
            #print(word)
            den=den+1;
            vec=vec+np.array(getWordVec(word,embeddingmodel))
        #vec=vec/den;
        #return (vec.tolist());
        return vec.reshape(1, -1)

# %%
# %%time
#With wb_word2vec_model



sent_embeddings=[]
for sent in sentences:
    sent_embeddings.append(getPhraseEmbedding(sent,wb_word2vec_model))

question_embedding=getPhraseEmbedding(query,wb_word2vec_model)

dff = get_cosim(question_embedding,sent_embeddings).head(5)

dff
# Out:
# Wall time: 2.84 s
#         id  simscore                                             result
# 2332  2332  0.999760  access issue unable to access application unab...
# 4680  4680  0.999747  access issue unable to access application sear...
# 3905  3905  0.999664  access issue unable to access application enab...
# 4476  4476  0.999655  access issue unable to access application  epm...
# 1241  1241  0.999645  access issue unable to access application qa a...

# %%
for i in dff.index:
    print(i)
    print(dff['result'][i])
# Out:
# 2332
# access issue unable to access application unable to print  extreme slowness
# 4680
# access issue unable to access application search results inquiry
# 3905
# access issue unable to access application enable workday integration  sap gl in slhub qa
# 4476
# access issue unable to access application  epm plugin  install
# 1241
# access issue unable to access application qa approval
